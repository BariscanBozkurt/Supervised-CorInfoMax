# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
from visualization import perc, SetPlotRC, ApplyFont

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # CorInfoMax

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_CorInfoMax_CIFAR10.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 7)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list', 'forward_backward_weight_angle_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed       Model  \
# 0               1    0  CorInfoMax
# 1               1   10  CorInfoMax
# 2               1   20  CorInfoMax
# 3               1   30  CorInfoMax
# 4               1   40  CorInfoMax
# 5               1   50  CorInfoMax
# 6               1   60  CorInfoMax
# 7               1   70  CorInfoMax
# 8               1   80  CorInfoMax
# 9               1   90  CorInfoMax
# 10              2    0  CorInfoMax
# 11              2   10  CorInfoMax
# 12              2   20  CorInfoMax
# 13              2   30  CorInfoMax
# 14              2   40  CorInfoMax
# 15              2   50  CorInfoMax
# 16              2   60  CorInfoMax
# 17              2   70  CorInfoMax
# 18              2   80  CorInfoMax
# 19              2   90  CorInfoMax
# 20              3    0  CorInfoMax
# 21              3   10  CorInfoMax
# 22              3   20  CorInfoMax
# 23              3   30  CorInfoMax
# 24              3   40  CorInfoMax
# 25              3   50  CorInfoMax
# 26              3   60  CorInfoMax
# 27              3   70  CorInfoMax
# 28              3   80  CorInfoMax
# 29              3   90  CorInfoMax
# 30              4    0  CorInfoMax
# 31              4   10  CorInfoMax
# 32              4   20  CorInfoMax
# 33              4   30  CorInfoMax
# 34              4   40  CorInfoMax
# 35              4   50  CorInfoMax
# 36              4   60  CorInfoMax
# 37              4   70  CorInfoMax
# 38              4   80  CorInfoMax
# 39              4   90  CorInfoMax
#
#                                           Hyperparams  \
# 0   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 1   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 2   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 3   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 4   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 5   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 6   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 7   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 8   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 9   {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 10  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 11  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 12  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 13  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 14  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 15  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 16  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 17  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 18  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 19  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 20  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 21  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 22  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 23  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 24  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 25  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 26  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 27  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 28  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 29  {'lr_start': {'ff': [0.07, 0.03], 'fb': [nan, ...
# 30  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 31  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 32  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 33  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 34  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 35  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 36  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 37  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 38  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
# 39  {'lr_start': {'ff': [0.08, 0.04], 'fb': [nan, ...
#
#                                          Trn_ACC_list  \
# 0   [0.33636, 0.39588, 0.43438, 0.45694, 0.47564, ...
# 1   [0.32872, 0.40028, 0.43438, 0.46188, 0.4791, 0...
# 2   [0.30438, 0.39652, 0.43574, 0.4591, 0.47888, 0...
# 3   [0.33898, 0.39764, 0.43542, 0.46066, 0.479, 0....
# 4   [0.33752, 0.40102, 0.4358, 0.45876, 0.48192, 0...
# 5   [0.3441, 0.39884, 0.43218, 0.4601, 0.47802, 0....
# 6   [0.33686, 0.39798, 0.43086, 0.46072, 0.4793, 0...
# 7   [0.3499, 0.4021, 0.43586, 0.45852, 0.47956, 0....
# 8   [0.33364, 0.3939, 0.4296, 0.45624, 0.47738, 0....
# 9   [0.31504, 0.38724, 0.42854, 0.4548, 0.4734, 0....
# 10  [0.35438, 0.41598, 0.4498, 0.47134, 0.49126, 0...
# 11  [0.35396, 0.41686, 0.4509, 0.4776, 0.49488, 0....
# 12  [0.3455, 0.4131, 0.4522, 0.47456, 0.49696, 0.5...
# 13  [0.3548, 0.41358, 0.45142, 0.47536, 0.49616, 0...
# 14  [0.35834, 0.4199, 0.45322, 0.47428, 0.49948, 0...
# 15  [0.35808, 0.41412, 0.4491, 0.47424, 0.49292, 0...
# 16  [0.35182, 0.41732, 0.4477, 0.475, 0.49732, 0.5...
# 17  [0.3632, 0.41656, 0.45078, 0.47324, 0.49426, 0...
# 18  [0.3511, 0.40946, 0.44666, 0.47232, 0.49394, 0...
# 19  [0.34518, 0.40628, 0.4478, 0.4705, 0.49102, 0....
# 20  [0.33636, 0.39568, 0.43436, 0.45664, 0.47608, ...
# 21  [0.32876, 0.4001, 0.4344, 0.4613, 0.47938, 0.4...
# 22  [0.30428, 0.39662, 0.43604, 0.45874, 0.47828, ...
# 23  [0.33888, 0.39762, 0.4357, 0.46126, 0.47964, 0...
# 24  [0.33754, 0.40114, 0.43592, 0.45892, 0.48274, ...
# 25  [0.34414, 0.399, 0.43222, 0.45978, 0.47678, 0....
# 26  [0.33688, 0.39818, 0.4313, 0.46008, 0.47864, 0...
# 27  [0.34964, 0.4025, 0.4364, 0.4584, 0.47924, 0.4...
# 28  [0.33362, 0.39296, 0.42956, 0.45674, 0.47708, ...
# 29  [0.31492, 0.38714, 0.42922, 0.45456, 0.47338, ...
# 30  [0.35456, 0.41506, 0.44916, 0.47182, 0.4916, 0...
# 31  [0.35376, 0.4169, 0.4504, 0.47734, 0.49532, 0....
# 32  [0.3455, 0.4128, 0.45152, 0.47492, 0.49568, 0....
# 33  [0.35482, 0.41296, 0.45154, 0.47518, 0.49548, ...
# 34  [0.35826, 0.42034, 0.45306, 0.47442, 0.49928, ...
# 35  [0.35814, 0.41422, 0.44906, 0.47542, 0.493, 0....
# 36  [0.35186, 0.41728, 0.4472, 0.47512, 0.49656, 0...
# 37  [0.36312, 0.41656, 0.45106, 0.47318, 0.49416, ...
# 38  [0.35108, 0.40952, 0.44708, 0.47192, 0.4933, 0...
# 39  [0.3451, 0.40604, 0.44728, 0.47054, 0.4912, 0....
#
#                                          Tst_ACC_list  \
# 0   [0.3272, 0.3881, 0.4216, 0.4379, 0.4501, 0.466...
# 1   [0.3275, 0.3916, 0.4209, 0.4393, 0.4597, 0.467...
# 2   [0.2958, 0.3944, 0.4294, 0.447, 0.4608, 0.4685...
# 3   [0.3391, 0.3949, 0.424, 0.442, 0.4545, 0.4643,...
# 4   [0.3384, 0.392, 0.4216, 0.4389, 0.4581, 0.4652...
# 5   [0.3427, 0.3899, 0.4219, 0.4396, 0.4561, 0.464...
# 6   [0.3333, 0.3933, 0.4172, 0.4421, 0.4585, 0.470...
# 7   [0.35, 0.3964, 0.4218, 0.4355, 0.4514, 0.4595,...
# 8   [0.3373, 0.3932, 0.4256, 0.4429, 0.4548, 0.466...
# 9   [0.3166, 0.3829, 0.4239, 0.4434, 0.4572, 0.468...
# 10  [0.3444, 0.4052, 0.4339, 0.4486, 0.4621, 0.473...
# 11  [0.3552, 0.404, 0.435, 0.4525, 0.4704, 0.4792,...
# 12  [0.3411, 0.4084, 0.4406, 0.4573, 0.4679, 0.481...
# 13  [0.3548, 0.4077, 0.4347, 0.4542, 0.4707, 0.475...
# 14  [0.3587, 0.4041, 0.4323, 0.4489, 0.469, 0.4762...
# 15  [0.357, 0.4026, 0.432, 0.4512, 0.4675, 0.4748,...
# 16  [0.346, 0.41, 0.4341, 0.4559, 0.4717, 0.4824, ...
# 17  [0.3605, 0.4074, 0.4362, 0.4467, 0.4624, 0.472...
# 18  [0.3507, 0.4067, 0.4364, 0.4505, 0.4651, 0.478...
# 19  [0.344, 0.4015, 0.4379, 0.4533, 0.4666, 0.4783...
# 20  [0.3269, 0.3885, 0.4214, 0.4384, 0.4487, 0.464...
# 21  [0.3273, 0.3915, 0.4217, 0.4395, 0.4592, 0.467...
# 22  [0.2959, 0.3944, 0.4304, 0.4452, 0.4609, 0.468...
# 23  [0.3396, 0.3939, 0.4237, 0.442, 0.4566, 0.466,...
# 24  [0.3382, 0.3914, 0.4215, 0.4373, 0.4581, 0.463...
# 25  [0.3427, 0.3899, 0.4217, 0.4378, 0.4553, 0.464...
# 26  [0.3334, 0.3931, 0.4172, 0.4432, 0.4589, 0.469...
# 27  [0.3503, 0.3957, 0.4221, 0.4354, 0.4519, 0.461...
# 28  [0.3371, 0.3921, 0.4247, 0.4411, 0.4557, 0.465...
# 29  [0.3168, 0.3834, 0.4232, 0.4428, 0.456, 0.4694...
# 30  [0.3444, 0.4056, 0.4346, 0.4485, 0.4617, 0.473...
# 31  [0.355, 0.4045, 0.4348, 0.4524, 0.4685, 0.48, ...
# 32  [0.3413, 0.4081, 0.4394, 0.4578, 0.468, 0.4813...
# 33  [0.3545, 0.4079, 0.4347, 0.4533, 0.4702, 0.476...
# 34  [0.3587, 0.4047, 0.4329, 0.4511, 0.4667, 0.477...
# 35  [0.3576, 0.4019, 0.431, 0.4516, 0.4663, 0.4743...
# 36  [0.3463, 0.4096, 0.4337, 0.4565, 0.472, 0.4839...
# 37  [0.3604, 0.4082, 0.4356, 0.4478, 0.4621, 0.473...
# 38  [0.3512, 0.4077, 0.436, 0.4507, 0.4646, 0.477,...
# 39  [0.3438, 0.4007, 0.4377, 0.4529, 0.4673, 0.479...
#
#                    forward_backward_weight_angle_list  Trn_ACC  Tst_ACC
# 0   [[89.96092987060547], [89.47801208496094], [88...  0.63040   0.5130
# 1   [[90.13799285888672], [89.88963317871094], [89...  0.62774   0.5161
# 2   [[89.70185852050781], [89.10952758789062], [88...  0.63216   0.5169
# 3   [[90.49340057373047], [89.96391296386719], [89...  0.62966   0.5126
# 4   [[89.3494873046875], [89.14669799804688], [88....  0.63290   0.5138
# 5   [[89.42311096191406], [88.8380355834961], [87....  0.62702   0.5117
# 6   [[89.42182922363281], [89.06783294677734], [88...  0.63428   0.5205
# 7   [[89.52362823486328], [88.96964263916016], [88...  0.63114   0.5140
# 8   [[90.96546173095703], [90.25321197509766], [89...  0.63134   0.5159
# 9   [[91.56926727294922], [91.17434692382812], [90...  0.63250   0.5214
# 10  [[89.96051788330078], [89.2210922241211], [88....  0.65300   0.5230
# 11  [[90.1380844116211], [89.72038269042969], [88....  0.65386   0.5212
# 12  [[89.70159912109375], [88.9116439819336], [88....  0.65816   0.5221
# 13  [[90.49285125732422], [89.67411041259766], [88...  0.65432   0.5209
# 14  [[89.34986114501953], [88.91513061523438], [87...  0.65474   0.5238
# 15  [[89.42295837402344], [88.55130004882812], [87...  0.65502   0.5212
# 16  [[89.4211654663086], [88.8219223022461], [87.8...  0.65648   0.5250
# 17  [[89.52247619628906], [88.7071304321289], [87....  0.65680   0.5230
# 18  [[90.96466064453125], [90.02580261230469], [88...  0.65514   0.5301
# 19  [[91.56912994384766], [91.00616455078125], [89...  0.65504   0.5225
# 20  [[89.96092987060547], [89.4780044555664], [88....  0.63132   0.5149
# 21  [[90.13799285888672], [89.88963317871094], [89...  0.62868   0.5116
# 22  [[89.70185852050781], [89.10952758789062], [88...  0.63186   0.5145
# 23  [[90.49340057373047], [89.96391296386719], [89...  0.62880   0.5097
# 24  [[89.3494873046875], [89.1467056274414], [88.3...  0.63230   0.5144
# 25  [[89.42311096191406], [88.8380355834961], [87....  0.62902   0.5146
# 26  [[89.42182922363281], [89.06784057617188], [88...  0.63300   0.5164
# 27  [[89.52362823486328], [88.96965026855469], [88...  0.63168   0.5142
# 28  [[90.96546173095703], [90.25321197509766], [89...  0.63052   0.5155
# 29  [[91.56926727294922], [91.17434692382812], [90...  0.63252   0.5230
# 30  [[89.96051788330078], [89.2210922241211], [88....  0.65438   0.5245
# 31  [[90.1380844116211], [89.72039031982422], [88....  0.65396   0.5207
# 32  [[89.70159912109375], [88.9116439819336], [88....  0.65736   0.5218
# 33  [[90.49285125732422], [89.67411041259766], [88...  0.65478   0.5200
# 34  [[89.34986114501953], [88.9151382446289], [87....  0.65518   0.5231
# 35  [[89.42295837402344], [88.55130004882812], [87...  0.65514   0.5225
# 36  [[89.4211654663086], [88.82192993164062], [87....  0.65542   0.5250
# 37  [[89.52247619628906], [88.7071304321289], [87....  0.65566   0.5230
# 38  [[90.96466064453125], [90.02581024169922], [88...  0.65370   0.5294
# 39  [[91.56912994384766], [91.00616455078125], [89...  0.65456   0.5229

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.630914  0.51559     0.002277     0.003274
# 1               2  0.655256  0.52328     0.001513     0.002712
# 2               3  0.630970  0.51488     0.001622     0.003450
# 3               4  0.655014  0.52329     0.001034     0.002632

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting #= 1
# Out:
# 2.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
# data = np.array(df_results.iloc[0]['Tst_ACC_list'])[np.newaxis]#.apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2')
plt.fill_between(x, perc_25, perc_75, alpha=0.25, linewidth=0, color='#006BB2')


gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
plt.title("")
plt.axis([0.0,50,mean_[0] - 0.01,0.53])
ApplyFont(plt.gca())
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # CSM

# %%
# df_results = pd.read_pickle(r"../Results/simulation_results_CSM_CIFAR10.pkl")
# df_results.columns

# %%
# df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
# df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
# df_results

# %%
# df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
# df_setting

# %%
# best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
# best_setting

# %%
# data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# # compute the mean, 25/75 percentiles, and standard deviation
# mean_, perc_25, perc_75, std_data = perc(data)

# x = np.arange(1, mean_.shape[0]+1)
# fh2=plt.figure(figsize=(10, 6), dpi=80)
# plt.plot(x, mean_, linewidth=4, color='#006BB2')
# plt.fill_between(x, perc_25, perc_75, alpha=0.25, linewidth=0, color='#006BB2')


# gh=plt.grid(linewidth=2)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
# plt.ylabel('Test Accuracy',fontsize=25)
# plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("")
# plt.axis([0.0,50,mean_[0] - 0.01,0.985])
# ApplyFont(plt.gca())

# %% [markdown]
# # EP

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_EP_CIFAR10_V2.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (34, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed Model  \
# 0               1    0    EP
# 1               1   10    EP
# 2               1   20    EP
# 3               1   30    EP
# 4               1   40    EP
# 5               1   50    EP
# 6               1   60    EP
# 7               1   70    EP
# 8               1   80    EP
# 9               1   90    EP
# 10              2    0    EP
# 11              2   10    EP
# 12              2   20    EP
# 13              2   30    EP
# 14              2   40    EP
# 15              2   50    EP
# 16              2   60    EP
# 17              2   70    EP
# 18              2   80    EP
# 19              2   90    EP
# 20              3    0    EP
# 21              3   10    EP
# 22              3   20    EP
# 23              3   30    EP
# 24              3   40    EP
# 25              3   50    EP
# 26              3   60    EP
# 27              3   70    EP
# 28              3   80    EP
# 29              3   90    EP
# 30              4    0    EP
# 31              4   10    EP
# 32              4   20    EP
# 33              4   30    EP
#
#                                           Hyperparams  \
# 0   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 1   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 2   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 3   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 4   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 5   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 6   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 7   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 8   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 9   {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 10  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 11  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 12  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 13  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 14  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 15  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 16  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 17  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 18  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 19  {'alphas_W': [0.1, 0.05], 'T1': 20, 'T2': 4, '...
# 20  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 21  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 22  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 23  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 24  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 25  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 26  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 27  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 28  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 29  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 30  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 31  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 32  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
# 33  {'alphas_W': [0.07, 0.03], 'T1': 20, 'T2': 4, ...
#
#                                          Trn_ACC_list  \
# 0   [0.41838, 0.48088, 0.51152, 0.52852, 0.5291, 0...
# 1   [0.44066, 0.44422, 0.50338, 0.52074, 0.54794, ...
# 2   [0.40046, 0.45514, 0.47478, 0.51494, 0.53376, ...
# 3   [0.39372, 0.45712, 0.51948, 0.50366, 0.52786, ...
# 4   [0.44646, 0.45838, 0.50302, 0.51842, 0.543, 0....
# 5   [0.42292, 0.48272, 0.4744, 0.48914, 0.5265, 0....
# 6   [0.44162, 0.46774, 0.47346, 0.518, 0.52882, 0....
# 7   [0.4042, 0.44844, 0.45862, 0.50222, 0.49962, 0...
# 8   [0.42598, 0.45002, 0.51832, 0.4998, 0.53982, 0...
# 9   [0.45402, 0.44004, 0.5114, 0.53054, 0.48512, 0...
# 10  [0.41878, 0.48114, 0.51204, 0.5292, 0.52996, 0...
# 11  [0.44122, 0.44502, 0.50434, 0.52214, 0.5487, 0...
# 12  [0.40058, 0.45564, 0.47542, 0.5149, 0.53402, 0...
# 13  [0.3941, 0.4579, 0.51998, 0.50442, 0.52826, 0....
# 14  [0.44624, 0.45876, 0.504, 0.51886, 0.54354, 0....
# 15  [0.42346, 0.4834, 0.47488, 0.48966, 0.52682, 0...
# 16  [0.44204, 0.46838, 0.47446, 0.51948, 0.52962, ...
# 17  [0.40458, 0.44904, 0.45918, 0.50288, 0.50034, ...
# 18  [0.42556, 0.45044, 0.51794, 0.50028, 0.54102, ...
# 19  [0.45396, 0.44038, 0.51224, 0.5314, 0.48582, 0...
# 20  [0.42796, 0.49844, 0.52942, 0.54536, 0.53934, ...
# 21  [0.46224, 0.48758, 0.5325, 0.5416, 0.5723, 0.5...
# 22  [0.41654, 0.49126, 0.51268, 0.53412, 0.5619, 0...
# 23  [0.40632, 0.46324, 0.5244, 0.5084, 0.5475, 0.5...
# 24  [0.46576, 0.47014, 0.51724, 0.537, 0.559, 0.59...
# 25  [0.43346, 0.50222, 0.51494, 0.51426, 0.5408, 0...
# 26  [0.44608, 0.49596, 0.50506, 0.54782, 0.54876, ...
# 27  [0.43464, 0.4562, 0.49808, 0.5263, 0.52436, 0....
# 28  [0.45352, 0.47602, 0.52994, 0.52258, 0.56182, ...
# 29  [0.45432, 0.4887, 0.52498, 0.53148, 0.51776, 0...
# 30  [0.4289, 0.49874, 0.53016, 0.54652, 0.53988, 0...
# 31  [0.46314, 0.48818, 0.5336, 0.54176, 0.57318, 0...
# 32  [0.4165, 0.49178, 0.51306, 0.53364, 0.56218, 0...
# 33  [0.40684, 0.46434, 0.52522, 0.50882, 0.54822, ...
#
#                                          Tst_ACC_list  Trn_ACC  Tst_ACC
# 0   [0.3924, 0.443, 0.464, 0.4648, 0.4621, 0.4415,...  0.95726   0.4769
# 1   [0.411, 0.4085, 0.4602, 0.4663, 0.4782, 0.4877...  0.96240   0.4865
# 2   [0.3718, 0.4288, 0.4209, 0.4564, 0.46, 0.4594,...  0.96104   0.4890
# 3   [0.3674, 0.414, 0.4695, 0.4451, 0.4583, 0.4585...  0.95686   0.4868
# 4   [0.4133, 0.4207, 0.4499, 0.4633, 0.4784, 0.485...  0.96006   0.4910
# 5   [0.3938, 0.4517, 0.4246, 0.4341, 0.4567, 0.491...  0.96012   0.4856
# 6   [0.4091, 0.4357, 0.4335, 0.4622, 0.4553, 0.459...  0.96454   0.4973
# 7   [0.3767, 0.4161, 0.4143, 0.4451, 0.4368, 0.477...  0.95740   0.4928
# 8   [0.4046, 0.4159, 0.4722, 0.4503, 0.4763, 0.485...  0.95824   0.4927
# 9   [0.4241, 0.3993, 0.4637, 0.4745, 0.4192, 0.474...  0.95994   0.4956
# 10  [0.3923, 0.4432, 0.4641, 0.465, 0.463, 0.4422,...  0.95790   0.4839
# 11  [0.4116, 0.4094, 0.4607, 0.468, 0.4794, 0.4878...  0.96302   0.4916
# 12  [0.3723, 0.4297, 0.4218, 0.4573, 0.4604, 0.46,...  0.96092   0.4968
# 13  [0.3682, 0.4151, 0.4692, 0.445, 0.4589, 0.4596...  0.95758   0.4935
# 14  [0.4132, 0.4219, 0.4497, 0.4633, 0.4785, 0.486...  0.96028   0.4950
# 15  [0.3945, 0.4523, 0.4248, 0.4354, 0.4573, 0.492...  0.96100   0.4894
# 16  [0.4097, 0.436, 0.4337, 0.4627, 0.4556, 0.46, ...  0.96488   0.5012
# 17  [0.3771, 0.4166, 0.4146, 0.4446, 0.4381, 0.478...  0.95870   0.4994
# 18  [0.4056, 0.4164, 0.4716, 0.45, 0.4777, 0.4867,...  0.95884   0.4985
# 19  [0.4239, 0.4, 0.4632, 0.4759, 0.4202, 0.4754, ...  0.95974   0.4987
# 20  [0.4018, 0.4503, 0.4694, 0.4681, 0.4623, 0.462...  0.97524   0.4976
# 21  [0.4263, 0.4366, 0.4738, 0.4747, 0.4871, 0.494...  0.97258   0.4895
# 22  [0.3778, 0.4426, 0.4492, 0.4623, 0.4781, 0.475...  0.97214   0.4871
# 23  [0.3764, 0.4107, 0.4672, 0.4456, 0.4695, 0.478...  0.97134   0.4945
# 24  [0.4265, 0.4285, 0.4692, 0.4771, 0.4827, 0.491...  0.96896   0.4842
# 25  [0.4001, 0.4635, 0.4533, 0.4499, 0.4598, 0.493...  0.96964   0.4791
# 26  [0.4191, 0.4454, 0.4498, 0.4825, 0.4661, 0.474...  0.97160   0.4948
# 27  [0.3992, 0.4087, 0.4433, 0.4596, 0.4532, 0.489...  0.97054   0.4798
# 28  [0.427, 0.4321, 0.4698, 0.4606, 0.4843, 0.4908...  0.97092   0.4839
# 29  [0.4235, 0.4458, 0.464, 0.4649, 0.4384, 0.4889...  0.97248   0.4885
# 30  [0.4028, 0.4517, 0.4702, 0.4695, 0.4634, 0.463...  0.97588   0.5012
# 31  [0.4267, 0.4372, 0.4748, 0.4759, 0.4885, 0.496...  0.97280   0.4943
# 32  [0.3785, 0.4427, 0.4496, 0.4623, 0.4785, 0.475...  0.97248   0.4899
# 33  [0.3777, 0.4116, 0.4677, 0.4452, 0.4702, 0.479...  0.97156   0.4978

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.959786  0.48942     0.002455     0.005887
# 1               2  0.960286  0.49480     0.002295     0.005322
# 2               3  0.971544  0.48790     0.001755     0.006338
# 3               4  0.973180  0.49580     0.001875     0.004838

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 4.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2')
plt.fill_between(x, perc_25, perc_75, alpha=0.25, linewidth=0, color='#006BB2')


gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
plt.title("")
plt.axis([0.0,50,mean_[0] - 0.01,0.55])
ApplyFont(plt.gca())

# %% [markdown]
# # EP-Continual-Weight-Update

# %% [markdown]
# # PC

# %%
# df_results = pd.read_pickle(r"../Results/simulation_results_PC_CIFAR10.pkl")
# df_results.columns

# %%
# df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
# df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
# df_results

# %%
# df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
# df_setting

# %%
# best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
# best_setting #= 1

# %%
# data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# # compute the mean, 25/75 percentiles, and standard deviation
# mean_, perc_25, perc_75, std_data = perc(data)

# x = np.arange(1, mean_.shape[0]+1)
# fh2=plt.figure(figsize=(10, 6), dpi=80)
# plt.plot(x, mean_, linewidth=4, color='#006BB2')
# plt.fill_between(x, perc_25, perc_75, alpha=0.25, linewidth=0, color='#006BB2')


# gh=plt.grid(linewidth=2)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
# plt.ylabel('Test Accuracy',fontsize=25)
# plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("")
# plt.axis([0.0,50,mean_[0] - 0.01,0.985])
# ApplyFont(plt.gca())

# %% [markdown]
# # PC-Nudge

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_PCNudge_CIFAR10.pkl")
df_results.columns
# Out:
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed    Model  \
# 0               1    0  PCNudge
# 1               1   10  PCNudge
# 2               1   20  PCNudge
# 3               1   30  PCNudge
# 4               1   40  PCNudge
# 5               1   50  PCNudge
# 6               1   60  PCNudge
# 7               1   70  PCNudge
# 8               1   80  PCNudge
# 9               1   90  PCNudge
# 10              2    0  PCNudge
# 11              2   10  PCNudge
# 12              2   20  PCNudge
# 13              2   30  PCNudge
# 14              2   40  PCNudge
#
#                                           Hyperparams  \
# 0   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 1   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 2   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 3   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 4   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 5   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 6   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 7   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 8   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 9   {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 10  {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 11  {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 12  {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 13  {'lr': 0.001, 'supervised_lambda_weight': 0.00...
# 14  {'lr': 0.001, 'supervised_lambda_weight': 0.00...
#
#                                          Trn_ACC_list  \
# 0   [0.42774, 0.4869, 0.51586, 0.54056, 0.55908, 0...
# 1   [0.41494, 0.4722, 0.51008, 0.53274, 0.55806, 0...
# 2   [0.45696, 0.49374, 0.53558, 0.55554, 0.58572, ...
# 3   [0.43854, 0.48132, 0.52272, 0.55068, 0.56612, ...
# 4   [0.44378, 0.4947, 0.52338, 0.54586, 0.5769, 0....
# 5   [0.43192, 0.4738, 0.49708, 0.5446, 0.55988, 0....
# 6   [0.42614, 0.4801, 0.52176, 0.54832, 0.5653, 0....
# 7   [0.42564, 0.48128, 0.51242, 0.5482, 0.56336, 0...
# 8   [0.41434, 0.48368, 0.50268, 0.53646, 0.55744, ...
# 9   [0.41996, 0.47564, 0.5181, 0.53392, 0.56342, 0...
# 10  [0.43372, 0.49094, 0.52692, 0.5482, 0.56632, 0...
# 11  [0.4174, 0.48128, 0.5169, 0.54556, 0.5622, 0.5...
# 12  [0.45428, 0.49246, 0.53426, 0.55962, 0.58588, ...
# 13  [0.44142, 0.48414, 0.51878, 0.54772, 0.56328, ...
# 14  [0.44536, 0.48852, 0.52706, 0.54488, 0.5742, 0...
#
#                                          Tst_ACC_list  Trn_ACC  Tst_ACC
# 0   [0.4135, 0.454, 0.4661, 0.4771, 0.4843, 0.4862...  0.84774   0.4808
# 1   [0.3991, 0.444, 0.4648, 0.4772, 0.4825, 0.4977...  0.85716   0.4860
# 2   [0.4369, 0.4618, 0.488, 0.4924, 0.5052, 0.5089...  0.86086   0.4799
# 3   [0.4278, 0.4555, 0.4797, 0.4911, 0.4886, 0.501...  0.85934   0.4905
# 4   [0.4299, 0.4616, 0.4781, 0.4799, 0.5009, 0.502...  0.85520   0.5003
# 5   [0.4223, 0.4462, 0.4587, 0.4854, 0.488, 0.5029...  0.85812   0.4868
# 6   [0.408, 0.4426, 0.4798, 0.4883, 0.4876, 0.4909...  0.84610   0.4876
# 7   [0.4051, 0.4511, 0.4655, 0.4913, 0.4938, 0.506...  0.85156   0.4858
# 8   [0.4025, 0.4522, 0.4519, 0.4803, 0.482, 0.4893...  0.84956   0.4754
# 9   [0.4006, 0.4448, 0.4684, 0.4661, 0.4822, 0.474...  0.85788   0.4851
# 10  [0.4161, 0.4602, 0.4776, 0.4811, 0.4905, 0.487...  0.84208   0.4783
# 11  [0.4019, 0.4579, 0.4774, 0.4889, 0.4913, 0.505...  0.85476   0.4894
# 12  [0.4367, 0.4622, 0.4788, 0.4979, 0.5036, 0.505...  0.85114   0.4837
# 13  [0.4284, 0.4553, 0.4787, 0.4869, 0.49, 0.4979,...  0.85790   0.4768
# 14  [0.431, 0.4584, 0.4786, 0.4744, 0.4982, 0.4969...  0.84454   0.4943

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.854352  0.48582     0.005218     0.006709
# 1               2  0.850084  0.48450     0.006687     0.007390

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 1.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2')
plt.fill_between(x, perc_25, perc_75, alpha=0.25, linewidth=0, color='#006BB2')


gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
plt.title("")
plt.axis([0.0,50,mean_[0] - 0.01,0.53])
ApplyFont(plt.gca())

# %% [markdown]
# # Altogether

# %% [markdown]
# ### Read EP Results

# %%
df_results_ep = pd.read_pickle(r"../Results/simulation_results_EP_CIFAR10_V2.pkl")
df_results_ep['Trn_ACC'] = df_results_ep.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results_ep['Tst_ACC'] = df_results_ep.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_setting_ep = df_results_ep[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
best_setting_ep = df_setting_ep.iloc[df_setting_ep['Trn_ACC'].argmax()]['setting_number']
best_setting_ep = 2

data_ep_tst = np.stack(df_results_ep.loc[df_results_ep["setting_number"] == best_setting_ep]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
data_ep_trn = np.stack(df_results_ep.loc[df_results_ep["setting_number"] == best_setting_ep]['Trn_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_ep_tst, perc_25_ep_tst, perc_75_ep_tst, std_data_ep_tst = perc(data_ep_tst)
mean_ep_trn, perc_25_ep_trn, perc_75_ep_trn, std_data_ep_trn = perc(data_ep_trn)

# %% [markdown]
# ### Read CSM Results

# %% [markdown]
# ### Read PC Results

# %% [markdown]
# ### Read PC-Nudge Results

# %%
df_results_pcn = pd.read_pickle(r"../Results/simulation_results_PCNudge_CIFAR10.pkl")
df_results_pcn['Trn_ACC'] = df_results_pcn.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results_pcn['Tst_ACC'] = df_results_pcn.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_setting_pcn = df_results_pcn[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
best_setting_pcn = df_setting_pcn.iloc[df_setting_pcn['Trn_ACC'].argmax()]['setting_number']

data_pcn_tst = np.stack(df_results_pcn.loc[df_results_pcn["setting_number"] == best_setting_pcn]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
data_pcn_trn = np.stack(df_results_pcn.loc[df_results_pcn["setting_number"] == best_setting_pcn]['Trn_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_pcn_tst, perc_25_pcn_tst, perc_75_pcn_tst, std_data_pcn_tst = perc(data_pcn_tst)
mean_pcn_trn, perc_25_pcn_trn, perc_75_pcn_trn, std_data_pcn_trn = perc(data_pcn_trn)

# %% [markdown]
# ### Read CorInfoMax Results

# %%
df_results_corinfo = pd.read_pickle(r"../Results/simulation_results_CorInfoMax_CIFAR10.pkl")
df_results_corinfo['Trn_ACC'] = df_results_corinfo.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results_corinfo['Tst_ACC'] = df_results_corinfo.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_setting_corinfo = df_results_corinfo[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
best_setting_corinfo = df_setting_corinfo.iloc[df_setting_corinfo['Trn_ACC'].argmax()]['setting_number']
best_setting_corinfo  #= 1

data_corinfo_tst = np.stack(df_results_corinfo.loc[df_results_corinfo["setting_number"] == best_setting_corinfo]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
data_corinfo_trn = np.stack(df_results_corinfo.loc[df_results_corinfo["setting_number"] == best_setting_corinfo]['Trn_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_corinfo_tst, perc_25_corinfo_tst, perc_75_corinfo_tst, std_data_corinfo_tst = perc(data_corinfo_tst)
mean_corinfo_trn, perc_25_corinfo_trn, perc_75_corinfo_trn, std_data_corinfo_trn = perc(data_corinfo_trn)

# %%
x = np.arange(1, mean_corinfo_tst.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)

plt.plot(x, mean_corinfo_tst, linewidth=4, color='#006BB2', label = "CorInfoMax")
plt.fill_between(x, mean_corinfo_tst - std_data_corinfo_tst, mean_corinfo_tst + std_data_corinfo_tst, alpha=0.25, linewidth=0, color='#006BB2')

# plt.plot(x, mean_csm_tst, 'r--', linewidth=4, label = "CSM")
# plt.fill_between(x, mean_csm_tst - std_data_csm_tst, mean_csm_tst + std_data_csm_tst, color = 'red', alpha=0.25, linewidth=0)

plt.plot(x, mean_ep_tst, 'g--', linewidth=2, label = "EP")
plt.fill_between(x, mean_ep_tst - std_data_ep_tst, mean_ep_tst + std_data_ep_tst, color = 'green', alpha=0.25, linewidth=0)

# plt.plot(x, mean_pc_tst, 'b--', linewidth=4, label = "PC")
# plt.fill_between(x, mean_pc_tst - std_data_pc_tst, mean_pc_tst + std_data_pc_tst, color = 'blue', alpha=0.25, linewidth=0)

plt.plot(x, mean_pcn_tst, '--', color = "orange", linewidth=2, label = "PCN")
plt.fill_between(x, mean_pcn_tst - std_data_pcn_tst, mean_pcn_tst + std_data_pcn_tst, color = 'orange', alpha=0.25, linewidth=0)


gh=plt.grid(linewidth=1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
plt.title("Test Accuracies on CIFAR10",fontsize=25)
plt.legend(fontsize = 20, loc = "best")
plt.axis([0.0,50,mean_corinfo_tst[0] - 0.01,0.53])
ApplyFont(plt.gca())
plt.savefig('Figures/CorInfoMaxCIFAR10TestAccuracyComparison.pdf', format='pdf')

# %%
x = np.arange(1, mean_corinfo_trn.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)

plt.plot(x, mean_corinfo_trn, linewidth=4, color='#006BB2', label = "CorInfoMax")
plt.fill_between(x, mean_corinfo_trn - std_data_corinfo_trn, mean_corinfo_trn + std_data_corinfo_trn, alpha=0.25, linewidth=0, color='#006BB2')

# plt.plot(x, mean_csm_trn, 'r--', linewidth=4, label = "CSM")
# plt.fill_between(x, mean_csm_trn - std_data_csm_trn, mean_csm_trn + std_data_csm_trn, color = 'red', alpha=0.25, linewidth=0)

plt.plot(x, mean_ep_trn, 'g--', linewidth=2, label = "EP")
plt.fill_between(x, mean_ep_trn - std_data_ep_trn, mean_ep_trn + std_data_ep_trn, color = 'green', alpha=0.25, linewidth=0)

# plt.plot(x, mean_pc_trn, 'b--', linewidth=4, label = "PC")
# plt.fill_between(x, mean_pc_trn - std_data_pc_trn, mean_pc_trn + std_data_pc_trn, color = 'blue', alpha=0.25, linewidth=0)

plt.plot(x, mean_pcn_trn, '--', color = "orange", linewidth=2, label = "PCN")
plt.fill_between(x, mean_pcn_trn - std_data_pcn_trn, mean_pcn_trn + std_data_pcn_trn, color = 'orange', alpha=0.25, linewidth=0)


gh=plt.grid(linewidth=1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
plt.title("Train Accuracies on CIFAR10",fontsize=25)
plt.legend(fontsize = 20, loc = "best")
plt.axis([0.0,50,mean_corinfo_trn[0] - 0.01,1.001])
ApplyFont(plt.gca())
plt.savefig('Figures/CorInfoMaxCIFAR10TrainAccuracyComparison.pdf', format='pdf')
