# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
from visualization import perc, SetPlotRC, ApplyFont

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # MNIST

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_MNIST_2Layers_CrossEntropy_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 1   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 2   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 3   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 4   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 5   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 6   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 7   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 8   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 9   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 10  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 11  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 12  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 13  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 14  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 15  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 16  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 17  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 18  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 19  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 20  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 21  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 22  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 23  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 24  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 25  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 26  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 27  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 28  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 29  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 30  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 31  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 32  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 33  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 34  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 35  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 36  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 37  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 38  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 39  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
#
#                                          Trn_ACC_list  \
# 0   [0.97435, 0.9828166666666667, 0.99065, 0.9916,...
# 1   [0.96845, 0.9845666666666667, 0.98871666666666...
# 2   [0.9727333333333333, 0.9852166666666666, 0.988...
# 3   [0.9724666666666667, 0.9824166666666667, 0.988...
# 4   [0.9636666666666667, 0.9824166666666667, 0.99,...
# 5   [0.9712166666666666, 0.9842833333333333, 0.990...
# 6   [0.9734833333333334, 0.9820333333333333, 0.985...
# 7   [0.9716333333333333, 0.9840666666666666, 0.988...
df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.999493  0.98271     0.000298     0.001259
# 1               2  0.999123  0.98193     0.000416     0.001283
# 2               3  0.999432  0.98240     0.000595     0.001551
# 3               4  0.999215  0.98229     0.000444     0.000995

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 1.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.985])
ApplyFont(plt.gca())
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_MNIST_2Layers_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (60, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
# 40              5    0  MLP-BPTT
# 41              5   10  MLP-BPTT
# 42              5   20  MLP-BPTT
# 43              5   30  MLP-BPTT
# 44              5   40  MLP-BPTT
# 45              5   50  MLP-BPTT
# 46              5   60  MLP-BPTT
# 47              5   70  MLP-BPTT
# 48              5   80  MLP-BPTT
# 49              5   90  MLP-BPTT
# 50              6    0  MLP-BPTT
# 51              6   10  MLP-BPTT
# 52              6   20  MLP-BPTT
# 53              6   30  MLP-BPTT
# 54              6   40  MLP-BPTT
# 55              6   50  MLP-BPTT
# 56              6   60  MLP-BPTT
# 57              6   70  MLP-BPTT
# 58              6   80  MLP-BPTT
# 59              6   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 1   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 2   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 3   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 4   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 5   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 6   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 7   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 8   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 9   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 10  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 11  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 12  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 13  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 14  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 15  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 16  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 17  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 18  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 19  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 20  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 21  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 22  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 23  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 24  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 25  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 26  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 27  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 28  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 29  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 30  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 31  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 32  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 33  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 34  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 35  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 36  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 37  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 38  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 39  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 40  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 41  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 42  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 43  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 44  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 45  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 46  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 47  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 48  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 49  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 50  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 51  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 52  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 53  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 54  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 55  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 56  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 57  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 58  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 59  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
#
#                                          Trn_ACC_list  \
# 0   [0.97715, 0.98545, 0.9882333333333333, 0.99066...
# 1   [0.9778666666666667, 0.98435, 0.98801666666666...
# 2   [0.9774833333333334, 0.9852166666666666, 0.987...
# 3   [0.9772, 0.98435, 0.9878833333333333, 0.99045,...
# 4   [0.9781333333333333, 0.985, 0.9885, 0.99035, 0...
# 5   [0.97815, 0.98395, 0.98705, 0.9902, 0.99166666...
# 6   [0.978, 0.9835666666666667, 0.9876833333333334...
# 7   [0.97755, 0.9844666666666667, 0.98843333333333...
# 8   [0.9768666666666667, 0.9846833333333334, 0.987...
# 9   [0.9775333333333334, 0.98405, 0.98808333333333...
# 10  [0.97715, 0.98545, 0.9882333333333333, 0.99066...
# 11  [0.9778666666666667, 0.98435, 0.98801666666666...
# 12  [0.9774833333333334, 0.9852166666666666, 0.987...
# 13  [0.9772, 0.98435, 0.9878833333333333, 0.99045,...
# 14  [0.9781333333333333, 0.985, 0.9885, 0.99035, 0...
# 15  [0.97815, 0.98395, 0.98705, 0.9902, 0.99166666...
# 16  [0.978, 0.9835666666666667, 0.9876833333333334...
# 17  [0.97755, 0.9844666666666667, 0.98843333333333...
# 18  [0.9768666666666667, 0.9846833333333334, 0.987...
# 19  [0.9775333333333334, 0.98405, 0.98808333333333...
# 20  [0.97715, 0.98545, 0.9882333333333333, 0.99066...
# 21  [0.9778666666666667, 0.98435, 0.98801666666666...
# 22  [0.9774833333333334, 0.9852166666666666, 0.987...
# 23  [0.9772, 0.98435, 0.9878833333333333, 0.99045,...
# 24  [0.9781333333333333, 0.985, 0.9885, 0.99035, 0...
# 38  [0.971, 0.9761, 0.9759, 0.9784, 0.9788, 0.9794...  0.999083   0.9751
# 39  [0.9718, 0.9772, 0.9786, 0.9798, 0.9785, 0.979...  0.998950   0.9766
# 40  [0.9733, 0.9783, 0.9776, 0.9787, 0.9773, 0.979...  0.998983   0.9764
# 41  [0.9729, 0.9749, 0.9794, 0.9785, 0.9793, 0.978...  0.998983   0.9755
# 42  [0.971, 0.9764, 0.9769, 0.9787, 0.9792, 0.9789...  0.998917   0.9765
# 43  [0.972, 0.9779, 0.9784, 0.9781, 0.9766, 0.9766...  0.998950   0.9756
# 44  [0.9732, 0.9754, 0.9795, 0.9773, 0.9783, 0.978...  0.999233   0.9758
# 45  [0.9727, 0.9759, 0.9759, 0.9784, 0.9779, 0.980...  0.998917   0.9760
# 46  [0.9713, 0.9729, 0.9774, 0.9785, 0.9785, 0.980...  0.999050   0.9767
# 47  [0.9722, 0.9753, 0.979, 0.9789, 0.9804, 0.9794...  0.999083   0.9750
# 48  [0.971, 0.9761, 0.9759, 0.9784, 0.9788, 0.9794...  0.999150   0.9749
# 49  [0.9718, 0.9772, 0.9786, 0.9798, 0.9785, 0.979...  0.998917   0.9758
# 50  [0.9733, 0.9783, 0.9776, 0.9787, 0.9773, 0.979...  0.998967   0.9765
# 51  [0.9729, 0.9749, 0.9794, 0.9785, 0.9793, 0.978...  0.998883   0.9749
# 52  [0.971, 0.9764, 0.9769, 0.9787, 0.9792, 0.9789...  0.998967   0.9752
# 53  [0.972, 0.9779, 0.9784, 0.9781, 0.9766, 0.9766...  0.998917   0.9745
# 54  [0.9732, 0.9754, 0.9795, 0.9773, 0.9783, 0.978...  0.999150   0.9749
# 55  [0.9727, 0.9759, 0.9759, 0.9784, 0.9779, 0.980...  0.998933   0.9760
# 56  [0.9713, 0.9729, 0.9774, 0.9785, 0.9785, 0.980...  0.999017   0.9760
# 57  [0.9722, 0.9753, 0.979, 0.9789, 0.9804, 0.9794...  0.998950   0.9739
# 58  [0.971, 0.9761, 0.9759, 0.9784, 0.9788, 0.9794...  0.999150   0.9763
# 59  [0.9718, 0.9772, 0.9786, 0.9798, 0.9785, 0.979...  0.999033   0.9757

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.998985  0.97596     0.000096     0.000589
# 1               2  0.999007  0.97561     0.000096     0.000769
# 2               3  0.999007  0.97531     0.000095     0.000714
# 3               4  0.999015  0.97587     0.000082     0.000948
# 4               5  0.999018  0.97582     0.000109     0.000603
# 5               6  0.998997  0.97539     0.000092     0.000845

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 5.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.985])
ApplyFont(plt.gca())

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_MNIST_3Layers_V2.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 1   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 2   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 3   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 4   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 5   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 6   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 7   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 8   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 9   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 10  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 11  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 12  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 13  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 14  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 15  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 16  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 17  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 18  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 19  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 20  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 21  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 22  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 23  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 24  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 25  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 26  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 27  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 28  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 29  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 30  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 31  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 32  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 33  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 34  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 35  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 36  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 37  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 38  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 39  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.999548  0.97598     0.000108     0.001364
# 1               2  0.999545  0.97612     0.000096     0.000859
# 2               3  0.999693  0.97745     0.000057     0.001031
# 3               4  0.999563  0.97619     0.000131     0.000930

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 3.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.985])
ApplyFont(plt.gca())

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_MNIST_3Layers_CrossEntropy_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 1   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 2   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 3   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 4   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 5   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 6   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 7   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 8   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 9   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 10  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 11  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 12  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 13  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 14  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 15  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 16  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 17  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 18  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 19  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 20  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 21  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 22  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 23  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 24  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 25  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 26  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 27  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 28  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 29  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 30  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 31  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 32  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 33  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 34  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 35  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 36  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 37  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 38  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 39  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
#
#                                          Trn_ACC_list  \
# 0   [0.97005, 0.9809, 0.9817666666666667, 0.990633...
# 1   [0.9777333333333333, 0.9819166666666667, 0.986...
# 2   [0.9738666666666667, 0.9814333333333334, 0.983...
# 3   [0.9741, 0.9830333333333333, 0.986366666666666...
# 4   [0.97765, 0.9840833333333333, 0.98625, 0.9891,...
# 5   [0.9760333333333333, 0.9798166666666667, 0.986...
# 6   [0.9710666666666666, 0.9834666666666667, 0.987...
# 7   [0.9754166666666667, 0.9832, 0.986383333333333...
# 8   [0.97555, 0.978, 0.9875833333333334, 0.98485, ...
# 9   [0.97145, 0.9758666666666667, 0.98923333333333...
# 10  [0.97005, 0.9809, 0.9817666666666667, 0.990633...
# 11  [0.9777333333333333, 0.9819166666666667, 0.986...
# 12  [0.9738666666666667, 0.9814333333333334, 0.983...
# 13  [0.9741, 0.9830333333333333, 0.986366666666666...
# 14  [0.97765, 0.9840833333333333, 0.98625, 0.9891,...
# 15  [0.9760333333333333, 0.9798166666666667, 0.986...
# 16  [0.9710666666666666, 0.9834666666666667, 0.987...
# 17  [0.9754166666666667, 0.9832, 0.986383333333333...
# 18  [0.97555, 0.978, 0.9875833333333334, 0.98485, ...
# 19  [0.97145, 0.9758666666666667, 0.98923333333333...
# 20  [0.97005, 0.9809, 0.9817666666666667, 0.990633...
# 21  [0.9777333333333333, 0.9819166666666667, 0.986...
# 22  [0.9738666666666667, 0.9814333333333334, 0.983...
# 23  [0.9741, 0.9830333333333333, 0.986366666666666...
# 24  [0.97765, 0.9840833333333333, 0.98625, 0.9891,...
# 25  [0.9760333333333333, 0.9798166666666667, 0.986...
# 26  [0.9710666666666666, 0.9834666666666667, 0.987...
# 27  [0.9754166666666667, 0.9832, 0.986383333333333...
# 28  [0.97555, 0.978, 0.9875833333333334, 0.98485, ...
# 29  [0.97145, 0.9758666666666667, 0.98923333333333...
# 30  [0.97005, 0.9809, 0.9817666666666667, 0.990633...
# 31  [0.9777333333333333, 0.9819166666666667, 0.986...
# 25  [0.9708, 0.9697, 0.9734, 0.9804, 0.9758, 0.980...  0.998800   0.9831
# 26  [0.963, 0.9761, 0.9766, 0.9771, 0.9769, 0.9816...  0.999667   0.9832
# 27  [0.97, 0.9757, 0.9752, 0.9751, 0.9736, 0.9825,...  0.998967   0.9829
# 28  [0.9682, 0.9687, 0.976, 0.9706, 0.9815, 0.978,...  0.999400   0.9825
# 29  [0.963, 0.9653, 0.9774, 0.9728, 0.9785, 0.9814...  0.999317   0.9820
# 30  [0.9629, 0.9711, 0.9755, 0.9795, 0.9766, 0.975...  0.999017   0.9821
# 31  [0.9706, 0.9751, 0.9764, 0.9761, 0.9734, 0.976...  0.999067   0.9835
# 32  [0.964, 0.9738, 0.9749, 0.978, 0.9789, 0.978, ...  0.999183   0.9833
# 33  [0.968, 0.9752, 0.9763, 0.9777, 0.9785, 0.9804...  0.998667   0.9810
# 34  [0.9718, 0.9752, 0.9752, 0.9766, 0.9762, 0.980...  0.998800   0.9831
# 35  [0.9708, 0.9697, 0.9734, 0.9804, 0.9758, 0.980...  0.999150   0.9836
# 36  [0.963, 0.9761, 0.9766, 0.9771, 0.9769, 0.9816...  0.999300   0.9834
# 37  [0.97, 0.9757, 0.9752, 0.9751, 0.9736, 0.9825,...  0.998517   0.9819
# 38  [0.9682, 0.9687, 0.976, 0.9706, 0.9815, 0.978,...  0.997450   0.9808
# 39  [0.963, 0.9653, 0.9774, 0.9728, 0.9785, 0.9814...  0.998917   0.9840

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.999042  0.98290     0.000300     0.001182
# 1               2  0.998753  0.98177     0.000703     0.001332
# 2               3  0.999238  0.98275     0.000430     0.000785
# 3               4  0.998807  0.98267     0.000535     0.001137

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 3.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.985])
ApplyFont(plt.gca())

# %% [markdown]
# # Fashion MNIST

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_FashionMNIST_2Layers_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (60, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
# 40              5    0  MLP-BPTT
# 41              5   10  MLP-BPTT
# 42              5   20  MLP-BPTT
# 43              5   30  MLP-BPTT
# 44              5   40  MLP-BPTT
# 45              5   50  MLP-BPTT
# 46              5   60  MLP-BPTT
# 47              5   70  MLP-BPTT
# 48              5   80  MLP-BPTT
# 49              5   90  MLP-BPTT
# 50              6    0  MLP-BPTT
# 51              6   10  MLP-BPTT
# 52              6   20  MLP-BPTT
# 53              6   30  MLP-BPTT
# 54              6   40  MLP-BPTT
# 55              6   50  MLP-BPTT
# 56              6   60  MLP-BPTT
# 57              6   70  MLP-BPTT
# 58              6   80  MLP-BPTT
# 59              6   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 1   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 2   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 3   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 4   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 5   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 6   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 7   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 8   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 9   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 10  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 11  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 12  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 13  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 14  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 15  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 16  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 17  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 18  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 19  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 20  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 21  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 22  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 23  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 24  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 25  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 26  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 27  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 28  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 29  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 30  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 31  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 32  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 33  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 34  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 35  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 36  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 37  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 38  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 39  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 40  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 41  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 42  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 43  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 44  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 45  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 46  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 47  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 48  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 49  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 50  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 51  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 52  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 53  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 54  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 55  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 56  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 57  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 58  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 59  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 54  [0.8459, 0.8584, 0.8618, 0.8634, 0.8725, 0.876...  0.936483   0.8796
# 55  [0.8487, 0.8628, 0.8639, 0.8702, 0.8728, 0.873...  0.938317   0.8824
# 56  [0.8469, 0.8637, 0.8684, 0.8702, 0.8728, 0.878...  0.940083   0.8785
# 57  [0.8508, 0.8643, 0.8699, 0.8712, 0.8744, 0.877...  0.942050   0.8881
# 58  [0.8503, 0.8595, 0.8674, 0.874, 0.8723, 0.8786...  0.938350   0.8813
# 59  [0.8499, 0.8651, 0.8682, 0.8708, 0.8758, 0.873...  0.942567   0.8858

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.941148  0.88299     0.001654     0.002028
# 1               2  0.940455  0.88299     0.001836     0.002373
# 2               3  0.939902  0.88268     0.001918     0.002636
# 3               4  0.942442  0.88389     0.001436     0.002338
# 4               5  0.941522  0.88351     0.001795     0.002208
# 5               6  0.939983  0.88287     0.002048     0.003034

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 4.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.89])
ApplyFont(plt.gca())

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_FashionMNIST_2Layers_CrossEntropy_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 1   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 2   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 3   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 4   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 5   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 6   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 7   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 8   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 9   {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 10  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 11  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 12  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 13  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 14  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 15  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 16  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 17  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 18  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 19  {'lr': 0.001, 'lr_decay': 0.95, 'lr_decay_step...
# 20  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 21  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 22  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 23  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 24  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 25  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 26  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 27  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 28  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 29  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 30  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 31  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 32  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 33  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 34  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 35  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 36  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 37  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 38  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
# 39  {'lr': 0.001, 'lr_decay': 0.9, 'lr_decay_step'...
#
#                                          Trn_ACC_list  \
# 0   [0.87405, 0.8799166666666667, 0.89186666666666...
# 1   [0.8662833333333333, 0.8865, 0.890333333333333...
# 2   [0.8531333333333333, 0.8774333333333333, 0.897...
# 3   [0.8670666666666667, 0.8812666666666666, 0.894...
# 4   [0.8561666666666666, 0.8797333333333334, 0.883...
# 5   [0.8442166666666666, 0.8741333333333333, 0.889...
# 6   [0.8581833333333333, 0.88525, 0.88778333333333...
# 7   [0.8613666666666666, 0.8855, 0.893266666666666...
# 8   [0.8528666666666667, 0.8782, 0.892516666666666...
# 9   [0.8495833333333334, 0.8747333333333334, 0.893...
# 10  [0.87405, 0.8799166666666667, 0.89186666666666...
# 11  [0.8662833333333333, 0.8865, 0.890333333333333...
# 12  [0.8531333333333333, 0.8774333333333333, 0.897...
# 13  [0.8670666666666667, 0.8812666666666666, 0.894...
# 14  [0.8561666666666666, 0.8797333333333334, 0.883...
# 15  [0.8442166666666666, 0.8741333333333333, 0.889...
# 16  [0.8581833333333333, 0.88525, 0.88778333333333...
# 17  [0.8613666666666666, 0.8855, 0.893266666666666...
# 18  [0.8528666666666667, 0.8782, 0.892516666666666...
# 19  [0.8495833333333334, 0.8747333333333334, 0.893...
# 20  [0.87405, 0.8799166666666667, 0.89186666666666...
# 21  [0.8662833333333333, 0.8865, 0.890333333333333...
# 22  [0.8531333333333333, 0.8774333333333333, 0.897...
# 23  [0.8670666666666667, 0.8812666666666666, 0.894...
# 20  [0.8578, 0.8649, 0.869, 0.8755, 0.8795, 0.8704...  0.973050   0.8925
# 21  [0.8527, 0.8652, 0.8688, 0.8734, 0.8776, 0.877...  0.977117   0.8938
# 22  [0.8375, 0.8593, 0.8804, 0.8771, 0.8756, 0.874...  0.975917   0.8934
# 23  [0.851, 0.8607, 0.8743, 0.8634, 0.8766, 0.8828...  0.976400   0.8951
# 24  [0.837, 0.8615, 0.8599, 0.8684, 0.8795, 0.8755...  0.975267   0.8981
# 25  [0.8258, 0.8564, 0.8677, 0.8724, 0.8743, 0.882...  0.980500   0.8957
# 26  [0.848, 0.8667, 0.8665, 0.8718, 0.8761, 0.8765...  0.974883   0.8937
# 27  [0.8504, 0.8681, 0.8722, 0.8695, 0.8743, 0.882...  0.978700   0.8943
# 28  [0.8379, 0.8623, 0.876, 0.8755, 0.8774, 0.8786...  0.973767   0.8934
# 29  [0.8328, 0.8543, 0.8709, 0.8725, 0.8702, 0.882...  0.974883   0.8911
# 30  [0.8578, 0.8649, 0.869, 0.8755, 0.8795, 0.8704...  0.972033   0.8883
# 31  [0.8527, 0.8652, 0.8688, 0.8734, 0.8776, 0.877...  0.968067   0.8937
# 32  [0.8375, 0.8593, 0.8804, 0.8771, 0.8756, 0.874...  0.974617   0.8937
# 33  [0.851, 0.8607, 0.8743, 0.8634, 0.8766, 0.8828...  0.974817   0.8938
# 34  [0.837, 0.8615, 0.8599, 0.8684, 0.8795, 0.8755...  0.970733   0.8926
# 35  [0.8258, 0.8564, 0.8677, 0.8724, 0.8743, 0.882...  0.969450   0.8921
# 36  [0.848, 0.8667, 0.8665, 0.8718, 0.8761, 0.8765...  0.969817   0.8917
# 37  [0.8504, 0.8681, 0.8722, 0.8695, 0.8743, 0.882...  0.970933   0.8900
# 38  [0.8379, 0.8623, 0.876, 0.8755, 0.8774, 0.8786...  0.966250   0.8911
# 39  [0.8328, 0.8543, 0.8709, 0.8725, 0.8702, 0.882...  0.970967   0.8906

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.971678  0.89158     0.002711     0.002955
# 1               2  0.970552  0.89243     0.002604     0.002948
# 2               3  0.976048  0.89411     0.002252     0.001897
# 3               4  0.970768  0.89176     0.002650     0.001806

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 3.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.90])
ApplyFont(plt.gca())

# %% [markdown]
# # CIFAR10

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_CIFAR10_2Layers_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 1   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 2   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 3   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 4   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 5   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 6   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 7   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 8   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 9   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 10  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 11  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 12  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 13  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 14  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 15  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 16  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 17  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 18  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 19  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 20  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 21  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 22  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 23  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 24  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 25  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 26  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 27  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 28  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 29  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 30  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 31  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 32  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 33  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 34  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 35  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 36  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 37  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 38  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 39  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
#
#                                          Trn_ACC_list  \
# 0   [0.50666, 0.54752, 0.57834, 0.5926, 0.63134, 0...
# 1   [0.4913, 0.55182, 0.563, 0.60872, 0.63012, 0.6...
# 2   [0.49158, 0.53656, 0.56788, 0.60546, 0.62924, ...
# 3   [0.50556, 0.5492, 0.58202, 0.60918, 0.62412, 0...
# 4   [0.50688, 0.53944, 0.56652, 0.60188, 0.6238, 0...
# 34  [0.4725, 0.4802, 0.4945, 0.5123, 0.511, 0.5229...  0.98926   0.5255
# 35  [0.4779, 0.4809, 0.501, 0.5126, 0.5076, 0.5093...  0.98584   0.5333
# 36  [0.4647, 0.4912, 0.4952, 0.511, 0.508, 0.526, ...  0.98580   0.5288
# 37  [0.4537, 0.4832, 0.4975, 0.507, 0.5224, 0.5192...  0.98434   0.5295
# 38  [0.4589, 0.4858, 0.4905, 0.4992, 0.5253, 0.512...  0.98590   0.5299
# 39  [0.4694, 0.4992, 0.5036, 0.5134, 0.518, 0.5195...  0.98706   0.5278

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.982586  0.52612     0.001628     0.005866
# 1               2  0.982818  0.52696     0.001432     0.005571
# 2               3  0.983810  0.52598     0.001472     0.005408
# 3               4  0.986480  0.52751     0.001409     0.004006

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 4.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.55])
ApplyFont(plt.gca())

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_CIFAR10_2Layers_CrossEntropy_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 1   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 2   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 3   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 4   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 5   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 6   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 7   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 8   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 9   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 10  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 11  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 12  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 13  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 14  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 15  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 16  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 17  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 18  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 19  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 20  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 21  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 22  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 23  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 24  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 25  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 26  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 27  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 28  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 29  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 30  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 31  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 32  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 33  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 34  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 35  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 36  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 37  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 38  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 39  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
#
#                                          Trn_ACC_list  \
# 0   [0.50234, 0.54634, 0.58626, 0.5966, 0.63478, 0...
# 1   [0.50356, 0.54166, 0.57372, 0.61208, 0.63114, ...
# 2   [0.50276, 0.5439, 0.57904, 0.60238, 0.6348, 0....
# 3   [0.497, 0.54546, 0.58006, 0.60496, 0.6236, 0.6...
# 4   [0.49996, 0.54368, 0.57534, 0.60606, 0.63632, ...
# 5   [0.50472, 0.54236, 0.582, 0.60912, 0.62102, 0....
# 6   [0.499, 0.5437, 0.57806, 0.60626, 0.62616, 0.6...
# 7   [0.50072, 0.54168, 0.57508, 0.60854, 0.63358, ...
# 8   [0.50106, 0.54302, 0.56584, 0.60076, 0.64104, ...
# 9   [0.49572, 0.54632, 0.579, 0.6127, 0.62854, 0.6...
# 10  [0.50234, 0.54634, 0.58626, 0.5966, 0.63478, 0...
# 11  [0.50356, 0.54166, 0.57372, 0.61208, 0.63114, ...
# 12  [0.50276, 0.5439, 0.57904, 0.60238, 0.6348, 0....
# 13  [0.497, 0.54546, 0.58006, 0.60496, 0.6236, 0.6...
# 14  [0.49996, 0.54368, 0.57534, 0.60606, 0.63632, ...
# 15  [0.50472, 0.54236, 0.582, 0.60912, 0.62102, 0....
# 16  [0.499, 0.5437, 0.57806, 0.60626, 0.62616, 0.6...
# 17  [0.50072, 0.54168, 0.57508, 0.60854, 0.63358, ...
# 18  [0.50106, 0.54302, 0.56584, 0.60076, 0.64104, ...
# 19  [0.49572, 0.54632, 0.579, 0.6127, 0.62854, 0.6...
# 20  [0.50234, 0.54634, 0.58626, 0.5966, 0.63478, 0...
# 21  [0.50356, 0.54166, 0.57372, 0.61208, 0.63114, ...
# 17  [0.4757, 0.4968, 0.5104, 0.5277, 0.5332, 0.534...  0.98722   0.5412
# 18  [0.4787, 0.4953, 0.5038, 0.5263, 0.5363, 0.537...  0.98540   0.5298
# 19  [0.4742, 0.4966, 0.5156, 0.5272, 0.5344, 0.530...  0.98420   0.5355
# 20  [0.4713, 0.4989, 0.5241, 0.5147, 0.5259, 0.533...  0.98298   0.5317
# 21  [0.4849, 0.5011, 0.5085, 0.5289, 0.5285, 0.530...  0.98734   0.5391
# 22  [0.4713, 0.5015, 0.5263, 0.5254, 0.5301, 0.540...  0.98366   0.5281
# 23  [0.4768, 0.5039, 0.516, 0.5215, 0.5239, 0.5293...  0.98852   0.5373
# 24  [0.4812, 0.501, 0.5157, 0.5242, 0.5312, 0.5343...  0.97150   0.5265
# 25  [0.4782, 0.501, 0.5182, 0.5234, 0.5239, 0.5359...  0.98504   0.5279
# 26  [0.4754, 0.4942, 0.5137, 0.5261, 0.5238, 0.536...  0.98912   0.5432
# 27  [0.4757, 0.4968, 0.5104, 0.5277, 0.5332, 0.534...  0.99174   0.5435
# 28  [0.4787, 0.4953, 0.5038, 0.5263, 0.5363, 0.537...  0.98386   0.5333
# 29  [0.4742, 0.4966, 0.5156, 0.5272, 0.5344, 0.530...  0.97986   0.5395
# 30  [0.4713, 0.4989, 0.5241, 0.5147, 0.5259, 0.533...  0.98792   0.5379
# 31  [0.4849, 0.5011, 0.5085, 0.5289, 0.5285, 0.530...  0.98566   0.5412
# 32  [0.4713, 0.5015, 0.5263, 0.5254, 0.5301, 0.540...  0.99002   0.5375
# 33  [0.4768, 0.5039, 0.516, 0.5215, 0.5239, 0.5293...  0.99094   0.5398
# 34  [0.4812, 0.501, 0.5157, 0.5242, 0.5312, 0.5343...  0.98496   0.5315
# 35  [0.4782, 0.501, 0.5182, 0.5234, 0.5239, 0.5359...  0.99062   0.5343
# 36  [0.4754, 0.4942, 0.5137, 0.5261, 0.5238, 0.536...  0.98596   0.5448
# 37  [0.4757, 0.4968, 0.5104, 0.5277, 0.5332, 0.534...  0.99432   0.5484
# 38  [0.4787, 0.4953, 0.5038, 0.5263, 0.5363, 0.537...  0.99090   0.5397
# 39  [0.4742, 0.4966, 0.5156, 0.5272, 0.5344, 0.530...  0.99312   0.5410

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.978610  0.53454     0.005082     0.006215
# 1               2  0.982648  0.53313     0.007387     0.005707
# 2               3  0.984362  0.53501     0.005696     0.006376
# 3               4  0.989442  0.53961     0.003202     0.004831

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 4.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.55])
ApplyFont(plt.gca())

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_CIFAR10_3Layers_V2.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 1   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 2   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 3   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 4   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 5   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 6   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 7   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 8   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 9   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 10  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 11  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 12  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 13  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 14  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 15  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 16  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 17  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 18  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 19  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 20  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 21  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 22  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 23  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 24  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 25  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 26  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 27  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 28  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 29  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 30  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 31  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 32  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 33  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 34  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 35  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 36  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 37  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 38  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 39  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
#
#                                          Trn_ACC_list  \
# 0   [0.509, 0.55624, 0.606, 0.64406, 0.676, 0.7132...
# 1   [0.50442, 0.55986, 0.60448, 0.64878, 0.68442, ...
# 2   [0.50428, 0.55538, 0.6051, 0.64716, 0.68498, 0...
# 3   [0.51258, 0.56684, 0.6055, 0.64392, 0.68348, 0...
# 4   [0.50242, 0.56166, 0.60452, 0.63764, 0.68246, ...
# 5   [0.51102, 0.55686, 0.60766, 0.64956, 0.68152, ...
# 6   [0.50554, 0.55568, 0.61066, 0.64894, 0.6879, 0...
# 7   [0.49724, 0.55472, 0.59834, 0.64248, 0.67146, ...
# 8   [0.50454, 0.56696, 0.6044, 0.63436, 0.67956, 0...
# 9   [0.50868, 0.55788, 0.60488, 0.6476, 0.68208, 0...
# 10  [0.509, 0.55624, 0.606, 0.64406, 0.676, 0.7132...
# 11  [0.50442, 0.55986, 0.60448, 0.64878, 0.68442, ...
# 12  [0.50428, 0.55538, 0.6051, 0.64716, 0.68498, 0...
# 13  [0.51258, 0.56684, 0.6055, 0.64392, 0.68348, 0...
# 14  [0.50242, 0.56166, 0.60452, 0.63764, 0.68246, ...
# 15  [0.51102, 0.55686, 0.60766, 0.64956, 0.68152, ...
# 16  [0.50554, 0.55568, 0.61066, 0.64894, 0.6879, 0...
# 17  [0.49724, 0.55472, 0.59834, 0.64248, 0.67146, ...
# 18  [0.50454, 0.56696, 0.6044, 0.63436, 0.67956, 0...
# 19  [0.50868, 0.55788, 0.60488, 0.6476, 0.68208, 0...
# 20  [0.509, 0.55624, 0.606, 0.64406, 0.676, 0.7132...
# 21  [0.50442, 0.55986, 0.60448, 0.64878, 0.68442, ...
# 22  [0.50428, 0.55538, 0.6051, 0.64716, 0.68498, 0...
# 23  [0.51258, 0.56684, 0.6055, 0.64392, 0.68348, 0...
# 24  [0.50242, 0.56166, 0.60452, 0.63764, 0.68246, ...
# 25  [0.51102, 0.55686, 0.60766, 0.64956, 0.68152, ...
# 26  [0.50554, 0.55568, 0.61066, 0.64894, 0.6879, 0...
# 27  [0.49724, 0.55472, 0.59834, 0.64248, 0.67146, ...
# 28  [0.50454, 0.56696, 0.6044, 0.63436, 0.67956, 0...
# 29  [0.50868, 0.55788, 0.60488, 0.6476, 0.68208, 0...
# 30  [0.509, 0.55624, 0.606, 0.64406, 0.676, 0.7132...
# 31  [0.50442, 0.55986, 0.60448, 0.64878, 0.68442, ...
# 32  [0.50428, 0.55538, 0.6051, 0.64716, 0.68498, 0...
# 33  [0.51258, 0.56684, 0.6055, 0.64392, 0.68348, 0...
# 34  [0.50242, 0.56166, 0.60452, 0.63764, 0.68246, ...
# 35  [0.51102, 0.55686, 0.60766, 0.64956, 0.68152, ...
# 36  [0.50554, 0.55568, 0.61066, 0.64894, 0.6879, 0...
# 37  [0.49724, 0.55472, 0.59834, 0.64248, 0.67146, ...
# 38  [0.50454, 0.56696, 0.6044, 0.63436, 0.67956, 0...
# 39  [0.50868, 0.55788, 0.60488, 0.6476, 0.68208, 0...
#
#                                          Tst_ACC_list  Trn_ACC  Tst_ACC
# 31  [0.4822, 0.5105, 0.5294, 0.5443, 0.5477, 0.549...  0.99688   0.5543
# 32  [0.4763, 0.506, 0.5252, 0.5425, 0.5514, 0.549,...  0.99678   0.5568
# 33  [0.4851, 0.5181, 0.5288, 0.5457, 0.555, 0.5548...  0.99700   0.5598
# 34  [0.4737, 0.5082, 0.5266, 0.5374, 0.5513, 0.558...  0.99622   0.5529
# 35  [0.4836, 0.5109, 0.5331, 0.5404, 0.5493, 0.555...  0.99604   0.5553
# 36  [0.4754, 0.5042, 0.5364, 0.5444, 0.5616, 0.553...  0.99684   0.5462
# 37  [0.4649, 0.5065, 0.5195, 0.5347, 0.5491, 0.554...  0.99688   0.5549
# 38  [0.4777, 0.5161, 0.5296, 0.5311, 0.5524, 0.554...  0.99722   0.5547
# 39  [0.4773, 0.5071, 0.5327, 0.5408, 0.5519, 0.550...  0.99638   0.5540

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.995576  0.55339     0.000602     0.005169
# 1               2  0.995834  0.55308     0.000431     0.003627
# 2               3  0.996082  0.55352     0.000390     0.003656
# 3               4  0.996722  0.55490     0.000379     0.003883

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 4.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.57])
ApplyFont(plt.gca())

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_CIFAR10_3Layers_CrossEntropy_V2.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (40, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC'] = df_results.apply(lambda row: row['Trn_ACC_list'][-1], axis = 1)
df_results['Tst_ACC'] = df_results.apply(lambda row: row['Tst_ACC_list'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
# 20              3    0  MLP-BPTT
# 21              3   10  MLP-BPTT
# 22              3   20  MLP-BPTT
# 23              3   30  MLP-BPTT
# 24              3   40  MLP-BPTT
# 25              3   50  MLP-BPTT
# 26              3   60  MLP-BPTT
# 27              3   70  MLP-BPTT
# 28              3   80  MLP-BPTT
# 29              3   90  MLP-BPTT
# 30              4    0  MLP-BPTT
# 31              4   10  MLP-BPTT
# 32              4   20  MLP-BPTT
# 33              4   30  MLP-BPTT
# 34              4   40  MLP-BPTT
# 35              4   50  MLP-BPTT
# 36              4   60  MLP-BPTT
# 37              4   70  MLP-BPTT
# 38              4   80  MLP-BPTT
# 39              4   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 1   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 2   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 3   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 4   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 5   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 6   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 7   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 8   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 9   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 10  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 11  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 12  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 13  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 14  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 15  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 16  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 17  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 18  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 19  {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 20  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 21  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 22  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 23  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 24  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 25  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 26  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 27  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 28  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 29  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 30  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 31  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 32  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 33  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 34  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 35  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 36  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 37  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 38  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 39  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
#
#                                          Trn_ACC_list  \
# 0   [0.50368, 0.55142, 0.59786, 0.62892, 0.65234, ...
# 1   [0.50668, 0.5571, 0.59942, 0.63558, 0.67116, 0...
# 2   [0.5052, 0.5579, 0.5978, 0.63256, 0.67362, 0.6...
# 3   [0.50846, 0.56304, 0.59948, 0.63742, 0.66266, ...
# 4   [0.50078, 0.55622, 0.5958, 0.63492, 0.6656, 0....
# 5   [0.50814, 0.55352, 0.59684, 0.63122, 0.66412, ...
# 6   [0.50144, 0.55356, 0.59628, 0.63494, 0.673, 0....
# 7   [0.49414, 0.5486, 0.58214, 0.62892, 0.65112, 0...
# 8   [0.49986, 0.5589, 0.59338, 0.62434, 0.66674, 0...
# 9   [0.49594, 0.56034, 0.60214, 0.6303, 0.66782, 0...
# 10  [0.50368, 0.55142, 0.59786, 0.62892, 0.65234, ...
# 11  [0.50668, 0.5571, 0.59942, 0.63558, 0.67116, 0...
# 12  [0.5052, 0.5579, 0.5978, 0.63256, 0.67362, 0.6...
# 13  [0.50846, 0.56304, 0.59948, 0.63742, 0.66266, ...
# 14  [0.50078, 0.55622, 0.5958, 0.63492, 0.6656, 0....
# 15  [0.50814, 0.55352, 0.59684, 0.63122, 0.66412, ...
# 16  [0.50144, 0.55356, 0.59628, 0.63494, 0.673, 0....
# 17  [0.49414, 0.5486, 0.58214, 0.62892, 0.65112, 0...
# 18  [0.49986, 0.5589, 0.59338, 0.62434, 0.66674, 0...
# 19  [0.49594, 0.56034, 0.60214, 0.6303, 0.66782, 0...
# 20  [0.50368, 0.55142, 0.59786, 0.62892, 0.65234, ...
# 21  [0.50668, 0.5571, 0.59942, 0.63558, 0.67116, 0...
# 22  [0.5052, 0.5579, 0.5978, 0.63256, 0.67362, 0.6...
# 23  [0.50846, 0.56304, 0.59948, 0.63742, 0.66266, ...
# 24  [0.50078, 0.55622, 0.5958, 0.63492, 0.6656, 0....
# 25  [0.50814, 0.55352, 0.59684, 0.63122, 0.66412, ...
# 26  [0.50144, 0.55356, 0.59628, 0.63494, 0.673, 0....
# 27  [0.49414, 0.5486, 0.58214, 0.62892, 0.65112, 0...
# 28  [0.49986, 0.5589, 0.59338, 0.62434, 0.66674, 0...
# 29  [0.49594, 0.56034, 0.60214, 0.6303, 0.66782, 0...
# 30  [0.50368, 0.55142, 0.59786, 0.62892, 0.65234, ...
# 31  [0.50668, 0.5571, 0.59942, 0.63558, 0.67116, 0...
# 32  [0.5052, 0.5579, 0.5978, 0.63256, 0.67362, 0.6...
# 33  [0.50846, 0.56304, 0.59948, 0.63742, 0.66266, ...
# 34  [0.50078, 0.55622, 0.5958, 0.63492, 0.6656, 0....
# 35  [0.50814, 0.55352, 0.59684, 0.63122, 0.66412, ...
# 36  [0.50144, 0.55356, 0.59628, 0.63494, 0.673, 0....
# 37  [0.49414, 0.5486, 0.58214, 0.62892, 0.65112, 0...
# 38  [0.49986, 0.5589, 0.59338, 0.62434, 0.66674, 0...
# 39  [0.49594, 0.56034, 0.60214, 0.6303, 0.66782, 0...
#
#                                          Tst_ACC_list  Trn_ACC  Tst_ACC
# 0   [0.4818, 0.5033, 0.5317, 0.5428, 0.5463, 0.546...  0.98332   0.5518
# 1   [0.4855, 0.515, 0.5345, 0.5375, 0.5462, 0.5516...  0.98582   0.5619
# 2   [0.4821, 0.5136, 0.5315, 0.5405, 0.5499, 0.546...  0.99114   0.5631
# 3   [0.4889, 0.5171, 0.5323, 0.541, 0.5451, 0.5544...  0.97974   0.5504
# 4   [0.4793, 0.507, 0.5282, 0.5387, 0.5519, 0.55, ...  0.98400   0.5587
# 5   [0.4868, 0.5124, 0.5282, 0.5368, 0.553, 0.555,...  0.98540   0.5599
# 6   [0.4818, 0.5133, 0.5346, 0.5422, 0.5549, 0.552...  0.97632   0.5536
# 7   [0.4736, 0.5082, 0.5174, 0.5349, 0.5447, 0.552...  0.99160   0.5638
# 8   [0.4775, 0.5151, 0.5286, 0.5278, 0.5542, 0.548...  0.97528   0.5533
# 9   [0.4725, 0.5151, 0.5302, 0.542, 0.5471, 0.5484...  0.98792   0.5552
# 10  [0.4818, 0.5033, 0.5317, 0.5428, 0.5463, 0.546...  0.97944   0.5521
# 11  [0.4855, 0.515, 0.5345, 0.5375, 0.5462, 0.5516...  0.98664   0.5593
# 12  [0.4821, 0.5136, 0.5315, 0.5405, 0.5499, 0.546...  0.98878   0.5641
# 13  [0.4889, 0.5171, 0.5323, 0.541, 0.5451, 0.5544...  0.98068   0.5565
# 14  [0.4793, 0.507, 0.5282, 0.5387, 0.5519, 0.55, ...  0.98586   0.5645
# 15  [0.4868, 0.5124, 0.5282, 0.5368, 0.553, 0.555,...  0.99594   0.5638
# 16  [0.4818, 0.5133, 0.5346, 0.5422, 0.5549, 0.552...  0.99210   0.5653
# 17  [0.4736, 0.5082, 0.5174, 0.5349, 0.5447, 0.552...  0.98350   0.5502
# 18  [0.4775, 0.5151, 0.5286, 0.5278, 0.5542, 0.548...  0.98346   0.5510
# 19  [0.4725, 0.5151, 0.5302, 0.542, 0.5471, 0.5484...  0.98776   0.5620
# 20  [0.4818, 0.5033, 0.5317, 0.5428, 0.5463, 0.546...  0.99278   0.5617
# 21  [0.4855, 0.515, 0.5345, 0.5375, 0.5462, 0.5516...  0.99518   0.5599
# 22  [0.4821, 0.5136, 0.5315, 0.5405, 0.5499, 0.546...  0.98098   0.5521
# 23  [0.4889, 0.5171, 0.5323, 0.541, 0.5451, 0.5544...  0.98776   0.5522
# 24  [0.4793, 0.507, 0.5282, 0.5387, 0.5519, 0.55, ...  0.98168   0.5438
# 25  [0.4868, 0.5124, 0.5282, 0.5368, 0.553, 0.555,...  0.98932   0.5627
# 26  [0.4818, 0.5133, 0.5346, 0.5422, 0.5549, 0.552...  0.97906   0.5587
# 27  [0.4736, 0.5082, 0.5174, 0.5349, 0.5447, 0.552...  0.99108   0.5604
# 28  [0.4775, 0.5151, 0.5286, 0.5278, 0.5542, 0.548...  0.99110   0.5615
# 29  [0.4725, 0.5151, 0.5302, 0.542, 0.5471, 0.5484...  0.98452   0.5533
# 30  [0.4818, 0.5033, 0.5317, 0.5428, 0.5463, 0.546...  0.99412   0.5614
# 31  [0.4855, 0.515, 0.5345, 0.5375, 0.5462, 0.5516...  0.99470   0.5626
# 32  [0.4821, 0.5136, 0.5315, 0.5405, 0.5499, 0.546...  0.98554   0.5586
# 33  [0.4889, 0.5171, 0.5323, 0.541, 0.5451, 0.5544...  0.99426   0.5615
# 34  [0.4793, 0.507, 0.5282, 0.5387, 0.5519, 0.55, ...  0.99450   0.5627
# 35  [0.4868, 0.5124, 0.5282, 0.5368, 0.553, 0.555,...  0.99224   0.5591
# 36  [0.4818, 0.5133, 0.5346, 0.5422, 0.5549, 0.552...  0.99526   0.5658
# 37  [0.4736, 0.5082, 0.5174, 0.5349, 0.5447, 0.552...  0.99504   0.5584
# 38  [0.4775, 0.5151, 0.5286, 0.5278, 0.5542, 0.548...  0.98996   0.5593
# 39  [0.4725, 0.5151, 0.5302, 0.542, 0.5471, 0.5484...  0.99406   0.5647

# %%
df_setting = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std', 'Tst_ACC_std']] = df_results[['setting_number', 'Trn_ACC', 'Tst_ACC']].groupby('setting_number').std().reset_index()[['Trn_ACC', 'Tst_ACC']]
df_setting
# Out:
#    setting_number   Trn_ACC  Tst_ACC  Trn_ACC_std  Tst_ACC_std
# 0               1  0.984054  0.55717     0.005607     0.004917
# 1               2  0.986416  0.55888     0.005051     0.005993
# 2               3  0.987346  0.55663     0.005500     0.006067
# 3               4  0.992968  0.56141     0.003052     0.002580

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC'].argmax()]['setting_number']
best_setting
# Out:
# 4.0

# %%
data = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_, perc_25, perc_75, std_data = perc(data)

x = np.arange(1, mean_.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)
plt.plot(x, mean_, linewidth=4, color='#006BB2', label = "BPTT")
plt.fill_between(x, mean_ - std_data, mean_ + std_data, alpha=0.25, linewidth=0, color='#006BB2')

SetPlotRC()
gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Test Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on MNIST")
plt.legend(fontsize = 25, loc = "lower right")
plt.axis([0.0,50,mean_[0] - 0.01,0.57])
ApplyFont(plt.gca())

# %% [markdown]
# # CIFAR 100

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_CIFAR100_3Layers_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (80, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC_list_top1'] = df_results.apply(lambda row: np.array(row['Trn_ACC_list'])[:,0], axis = 1)
df_results['Trn_ACC_list_top5'] = df_results.apply(lambda row: np.array(row['Trn_ACC_list'])[:,1], axis = 1)
df_results['Tst_ACC_list_top1'] = df_results.apply(lambda row: np.array(row['Tst_ACC_list'])[:,0], axis = 1)
df_results['Tst_ACC_list_top5'] = df_results.apply(lambda row: np.array(row['Tst_ACC_list'])[:,1], axis = 1)

df_results['Trn_ACC_top1'] = df_results.apply(lambda row: row['Trn_ACC_list_top1'][-1], axis = 1)
df_results['Trn_ACC_top5'] = df_results.apply(lambda row: row['Trn_ACC_list_top5'][-1], axis = 1)
df_results['Tst_ACC_top1'] = df_results.apply(lambda row: row['Tst_ACC_list_top1'][-1], axis = 1)
df_results['Tst_ACC_top5'] = df_results.apply(lambda row: row['Tst_ACC_list_top5'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# ..            ...  ...       ...
# 75              8   50  MLP-BPTT
# 76              8   60  MLP-BPTT
# 77              8   70  MLP-BPTT
# 78              8   80  MLP-BPTT
# 79              8   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 1   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 2   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 3   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# 4   {'lr': 0.0001, 'lr_decay': 0.99, 'lr_decay_ste...
# ..                                                ...
# 75  {'lr': 6.666666666666667e-05, 'lr_decay': 0.9,...
# 76  {'lr': 6.666666666666667e-05, 'lr_decay': 0.9,...
# 77  {'lr': 6.666666666666667e-05, 'lr_decay': 0.9,...
# 78  {'lr': 6.666666666666667e-05, 'lr_decay': 0.9,...
# 79  {'lr': 6.666666666666667e-05, 'lr_decay': 0.9,...
#
#                                          Trn_ACC_list  \
# 0   [[0.16422, 0.40992], [0.20028, 0.46582], [0.23...
# 1   [[0.1556, 0.39746], [0.20214, 0.45918], [0.229...
# 2   [[0.16042, 0.40834], [0.19848, 0.4655], [0.238...
# 3   [[0.16256, 0.40474], [0.20386, 0.4606], [0.237...
# 4   [[0.16104, 0.39944], [0.20258, 0.46078], [0.23...
# ..                                                ...
# 75  [[0.1701, 0.43696], [0.22846, 0.51474], [0.257...
# 76  [[0.17398, 0.43172], [0.21844, 0.49784], [0.25...
# 77  [[0.1769, 0.4361], [0.21918, 0.49706], [0.2606...
# 78  [[0.17068, 0.42644], [0.21054, 0.5003], [0.252...
# 79  [[0.17984, 0.43748], [0.22578, 0.5036], [0.255...
#
#                                          Tst_ACC_list  \
# 0   [[0.1448, 0.3736], [0.1727, 0.4098], [0.1921, ...
# 1   [[0.1408, 0.3664], [0.1747, 0.412], [0.1905, 0...
# 2   [[0.145, 0.3742], [0.171, 0.4104], [0.1951, 0....
# 3   [[0.1493, 0.3705], [0.1739, 0.4179], [0.1943, ...
# 4   [[0.1435, 0.3632], [0.1739, 0.4076], [0.1953, ...
# ..                                                ...
# 75  [[0.1469, 0.3863], [0.1897, 0.4347], [0.207, 0...
# 76  [[0.1476, 0.3771], [0.18, 0.4245], [0.2035, 0....
# 77  [[0.1544, 0.3913], [0.1853, 0.4239], [0.2103, ...
# 78  [[0.1493, 0.3798], [0.1773, 0.4298], [0.2017, ...
# 79  [[0.1548, 0.3894], [0.1857, 0.4319], [0.2026, ...
#
#                                     Trn_ACC_list_top1  \
# 0   [0.16422, 0.20028, 0.23626, 0.26446, 0.2955, 0...
# 1   [0.1556, 0.20214, 0.22974, 0.26148, 0.28662, 0...
# 2   [0.16042, 0.19848, 0.23842, 0.26802, 0.29432, ...
# 3   [0.16256, 0.20386, 0.2373, 0.2659, 0.29674, 0....
# 4   [0.16104, 0.20258, 0.23734, 0.27092, 0.30006, ...
# ..                                                ...
# 75  [0.1701, 0.22846, 0.25718, 0.29548, 0.32676, 0...
# 76  [0.17398, 0.21844, 0.25722, 0.29616, 0.32686, ...
# 77  [0.1769, 0.21918, 0.26068, 0.29386, 0.32928, 0...
# 78  [0.17068, 0.21054, 0.25274, 0.29038, 0.32302, ...
# 79  [0.17984, 0.22578, 0.25594, 0.29438, 0.3254, 0...
#
#                                     Trn_ACC_list_top5  \
# 0   [0.40992, 0.46582, 0.50288, 0.53022, 0.55712, ...
# 1   [0.39746, 0.45918, 0.49482, 0.52218, 0.54388, ...
# 2   [0.40834, 0.4655, 0.50126, 0.5256, 0.55342, 0....
# 3   [0.40474, 0.4606, 0.50152, 0.52578, 0.55448, 0...
# 4   [0.39944, 0.46078, 0.50548, 0.53112, 0.54904, ...
# ..                                                ...
# 75  [0.43696, 0.51474, 0.5552, 0.59576, 0.626, 0.6...
# 76  [0.43172, 0.49784, 0.5469, 0.59328, 0.61898, 0...
# 77  [0.4361, 0.49706, 0.55534, 0.59258, 0.61956, 0...
# 78  [0.42644, 0.5003, 0.53688, 0.58302, 0.61456, 0...
# 79  [0.43748, 0.5036, 0.54868, 0.59006, 0.6181, 0....
#
#                                     Tst_ACC_list_top1  \
# 0   [0.1448, 0.1727, 0.1921, 0.2099, 0.2237, 0.229...
# 1   [0.1408, 0.1747, 0.1905, 0.206, 0.2184, 0.2252...
# 2   [0.145, 0.171, 0.1951, 0.2117, 0.2219, 0.2334,...
# 3   [0.1493, 0.1739, 0.1943, 0.2056, 0.2196, 0.231...
# 4   [0.1435, 0.1739, 0.1953, 0.2118, 0.2224, 0.227...
# ..                                                ...
# 75  [0.1469, 0.1897, 0.207, 0.2183, 0.2362, 0.2473...
# 76  [0.1476, 0.18, 0.2035, 0.2253, 0.2345, 0.245, ...
# 77  [0.1544, 0.1853, 0.2103, 0.218, 0.2353, 0.2487...
# 78  [0.1493, 0.1773, 0.2017, 0.2209, 0.2299, 0.244...
# 79  [0.1548, 0.1857, 0.2026, 0.2246, 0.2315, 0.240...
#
#                                     Tst_ACC_list_top5  Trn_ACC_top1  \
# 0   [0.3736, 0.4098, 0.4374, 0.4549, 0.4674, 0.468...       0.59068
# 1   [0.3664, 0.412, 0.4258, 0.448, 0.4579, 0.4624,...       0.57972
# 2   [0.3742, 0.4104, 0.4369, 0.4462, 0.4625, 0.465...       0.59770
# 3   [0.3705, 0.4179, 0.4367, 0.4473, 0.4568, 0.465...       0.58918
# 4   [0.3632, 0.4076, 0.4423, 0.4542, 0.4546, 0.453...       0.58512
# ..                                                ...           ...
# 75  [0.3863, 0.4347, 0.4647, 0.4743, 0.4926, 0.496...       0.78224
# 76  [0.3771, 0.4245, 0.4457, 0.4815, 0.4867, 0.492...       0.77394
# 77  [0.3913, 0.4239, 0.4616, 0.4748, 0.493, 0.4956...       0.77188
# 78  [0.3798, 0.4298, 0.4471, 0.4767, 0.4857, 0.494...       0.76104
# 79  [0.3894, 0.4319, 0.4518, 0.4758, 0.4874, 0.490...       0.76632
#
#     Trn_ACC_top5  Tst_ACC_top1  Tst_ACC_top5
# 0        0.64126        0.2430        0.3561
# 1        0.62594        0.2406        0.3510
# 2        0.64962        0.2459        0.3567
# 3        0.64854        0.2413        0.3534
# 4        0.63994        0.2431        0.3545
# ..           ...           ...           ...
# 75       0.83994        0.2657        0.4060
# 76       0.82958        0.2638        0.4039
# 77       0.83402        0.2690        0.4133
# 78       0.82570        0.2653        0.4021
# 79       0.82494        0.2644        0.4057
#
# [80 rows x 14 columns]

# %%
df_setting = df_results[['setting_number', 'Trn_ACC_top1', 'Tst_ACC_top1', 'Trn_ACC_top5', 'Tst_ACC_top5']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std_top1', 'Tst_ACC_std_top1', 'Trn_ACC_std_top5', 'Tst_ACC_std_top5']] = df_results[['setting_number', 'Trn_ACC_top1', 'Tst_ACC_top1', 'Trn_ACC_top5', 'Tst_ACC_top5']].groupby('setting_number').std().reset_index()[['Trn_ACC_top1', 'Tst_ACC_top1', 'Trn_ACC_top5', 'Tst_ACC_top5']]
df_setting
# Out:
#    setting_number  Trn_ACC_top1  Tst_ACC_top1  Trn_ACC_top5  Tst_ACC_top5  \
# 0               1      0.594116       0.24322      0.646270       0.35528
# 1               2      0.594488       0.24389      0.647040       0.35546
# 2               3      0.594600       0.24381      0.647168       0.35572
# 3               4      0.597286       0.24461      0.650720       0.35535
# 4               5      0.764086       0.26297      0.815542       0.39936
# 5               6      0.763994       0.26286      0.816766       0.39853
# 6               7      0.765216       0.26282      0.819828       0.40105
# 7               8      0.768982       0.26562      0.828492       0.40641
#
#    Trn_ACC_std_top1  Tst_ACC_std_top1  Trn_ACC_std_top5  Tst_ACC_std_top5
# 0          0.007898          0.002313          0.009279          0.004530
# 1          0.008458          0.003789          0.010087          0.003743
# 2          0.008020          0.003675          0.009248          0.004797
# 3          0.008161          0.003072          0.011030          0.004790
# 4          0.007500          0.001768          0.006334          0.004337
# 5          0.007189          0.002210          0.006052          0.002873
# 6          0.007211          0.001616          0.006366          0.004474
# 7          0.007061          0.001917          0.006084          0.003888

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC_top1'].argmax()]['setting_number']
best_setting
# Out:
# 8.0

# %%
data_top1 = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list_top1'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
data_top5 = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list_top5'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
# data = np.array(df_results.iloc[0]['Tst_ACC_list'])[np.newaxis]#.apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_top1, perc_25_top1, perc_75_top1, std_data_top1 = perc(data_top1)
mean_top5, perc_25_top5, perc_75_top5, std_data_top5 = perc(data_top5)

x = np.arange(1, mean_top1.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)

plt.plot(x, mean_top5, linewidth=4, color='k', label = "BPTT - Top-5 (%)")
plt.fill_between(x, mean_top5 - std_data_top5, mean_top5 + std_data_top5, alpha=0.25, linewidth=0, color='k')

plt.plot(x, mean_top1, linewidth=4, color='#006BB2', label = "BPTT - Top-1 (%)")
plt.fill_between(x, mean_top1 - std_data_top1, mean_top1 + std_data_top1, alpha=0.25, linewidth=0, color='#006BB2')


gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on CIFAR100")
plt.legend(fontsize = 25)
plt.axis([0.0,50,mean_top1[0] - 0.01,0.60])
ApplyFont(plt.gca())

# %%
df_results = pd.read_pickle(r"../Results/simulation_results_MLP_CIFAR100_3Layers_CrossEntropy_V1.pkl")
print(df_results.shape)
df_results.columns
# Out:
# (20, 6)
# Index(['setting_number', 'seed', 'Model', 'Hyperparams', 'Trn_ACC_list',
#        'Tst_ACC_list'],
#       dtype='object')

# %%
df_results['Trn_ACC_list_top1'] = df_results.apply(lambda row: np.array(row['Trn_ACC_list'])[:,0], axis = 1)
df_results['Trn_ACC_list_top5'] = df_results.apply(lambda row: np.array(row['Trn_ACC_list'])[:,1], axis = 1)
df_results['Tst_ACC_list_top1'] = df_results.apply(lambda row: np.array(row['Tst_ACC_list'])[:,0], axis = 1)
df_results['Tst_ACC_list_top5'] = df_results.apply(lambda row: np.array(row['Tst_ACC_list'])[:,1], axis = 1)

df_results['Trn_ACC_top1'] = df_results.apply(lambda row: row['Trn_ACC_list_top1'][-1], axis = 1)
df_results['Trn_ACC_top5'] = df_results.apply(lambda row: row['Trn_ACC_list_top5'][-1], axis = 1)
df_results['Tst_ACC_top1'] = df_results.apply(lambda row: row['Tst_ACC_list_top1'][-1], axis = 1)
df_results['Tst_ACC_top5'] = df_results.apply(lambda row: row['Tst_ACC_list_top5'][-1], axis = 1)
df_results
# Out:
#    setting_number seed     Model  \
# 0               1    0  MLP-BPTT
# 1               1   10  MLP-BPTT
# 2               1   20  MLP-BPTT
# 3               1   30  MLP-BPTT
# 4               1   40  MLP-BPTT
# 5               1   50  MLP-BPTT
# 6               1   60  MLP-BPTT
# 7               1   70  MLP-BPTT
# 8               1   80  MLP-BPTT
# 9               1   90  MLP-BPTT
# 10              2    0  MLP-BPTT
# 11              2   10  MLP-BPTT
# 12              2   20  MLP-BPTT
# 13              2   30  MLP-BPTT
# 14              2   40  MLP-BPTT
# 15              2   50  MLP-BPTT
# 16              2   60  MLP-BPTT
# 17              2   70  MLP-BPTT
# 18              2   80  MLP-BPTT
# 19              2   90  MLP-BPTT
#
#                                           Hyperparams  \
# 0   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 1   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 2   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 3   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 4   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 5   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 6   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 7   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 8   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 9   {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 10  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 11  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 12  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 13  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 14  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 15  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 16  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 17  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 18  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
# 19  {'lr': 0.0001, 'lr_decay': 0.9, 'lr_decay_step...
#
#                                          Trn_ACC_list  \
# 0   [[0.2152, 0.48404], [0.27004, 0.563], [0.32858...
# 1   [[0.20554, 0.47886], [0.2766, 0.5694], [0.3293...
# 2   [[0.21314, 0.4838], [0.27974, 0.56904], [0.328...
# 3   [[0.21102, 0.47792], [0.27898, 0.56624], [0.32...
# 4   [[0.21518, 0.4819], [0.27454, 0.56588], [0.325...
# 5   [[0.21788, 0.48276], [0.28354, 0.57084], [0.33...
# 6   [[0.21382, 0.48466], [0.28062, 0.56662], [0.32...
# 7   [[0.21312, 0.48778], [0.2752, 0.5663], [0.3299...
# 8   [[0.22086, 0.48822], [0.27306, 0.56332], [0.31...
# 9   [[0.21488, 0.4832], [0.2748, 0.56474], [0.3201...
# 10  [[0.2152, 0.48404], [0.27004, 0.563], [0.32858...
# 11  [[0.20554, 0.47886], [0.2766, 0.5694], [0.3293...
# 12  [[0.21314, 0.4838], [0.27974, 0.56904], [0.328...
# 13  [[0.21102, 0.47792], [0.27898, 0.56624], [0.32...
# 14  [[0.21518, 0.4819], [0.27454, 0.56588], [0.325...
# 15  [[0.21788, 0.48276], [0.28354, 0.57084], [0.33...
# 16  [[0.21382, 0.48466], [0.28062, 0.56662], [0.32...
# 17  [[0.21312, 0.48778], [0.2752, 0.5663], [0.3299...
# 18  [[0.22086, 0.48822], [0.27306, 0.56332], [0.31...
# 19  [[0.21488, 0.4832], [0.2748, 0.56474], [0.3201...
#
#                                          Tst_ACC_list  \
# 0   [[0.1895, 0.4468], [0.2239, 0.4901], [0.2533, ...
# 1   [[0.1831, 0.4404], [0.2258, 0.504], [0.2514, 0...
# 2   [[0.1863, 0.442], [0.2305, 0.499], [0.2511, 0....
# 3   [[0.1869, 0.4413], [0.2261, 0.4997], [0.2507, ...
# 4   [[0.1893, 0.4459], [0.2272, 0.4992], [0.2523, ...
# 5   [[0.1898, 0.4492], [0.23, 0.4989], [0.2573, 0....
# 6   [[0.1832, 0.4487], [0.2284, 0.5045], [0.2544, ...
# 7   [[0.1909, 0.4496], [0.2225, 0.5008], [0.2519, ...
# 8   [[0.1915, 0.4502], [0.2247, 0.4934], [0.2416, ...
# 9   [[0.1914, 0.447], [0.2348, 0.4975], [0.2437, 0...
# 10  [[0.1895, 0.4468], [0.2239, 0.4901], [0.2533, ...
# 11  [[0.1831, 0.4404], [0.2258, 0.504], [0.2514, 0...
# 12  [[0.1863, 0.442], [0.2305, 0.499], [0.2511, 0....
# 13  [[0.1869, 0.4413], [0.2261, 0.4997], [0.2507, ...
# 14  [[0.1893, 0.4459], [0.2272, 0.4992], [0.2523, ...
# 15  [[0.1898, 0.4492], [0.23, 0.4989], [0.2573, 0....
# 16  [[0.1832, 0.4487], [0.2284, 0.5045], [0.2544, ...
# 17  [[0.1909, 0.4496], [0.2225, 0.5008], [0.2519, ...
# 18  [[0.1915, 0.4502], [0.2247, 0.4934], [0.2416, ...
# 19  [[0.1914, 0.447], [0.2348, 0.4975], [0.2437, 0...
#
#                                     Trn_ACC_list_top1  \
# 0   [0.2152, 0.27004, 0.32858, 0.37734, 0.42328, 0...
# 1   [0.20554, 0.2766, 0.32936, 0.375, 0.42374, 0.4...
# 2   [0.21314, 0.27974, 0.32866, 0.3658, 0.41546, 0...
# 3   [0.21102, 0.27898, 0.32612, 0.37116, 0.42486, ...
# 4   [0.21518, 0.27454, 0.3253, 0.37888, 0.41928, 0...
# 5   [0.21788, 0.28354, 0.33224, 0.37614, 0.4221, 0...
# 6   [0.21382, 0.28062, 0.32742, 0.37868, 0.42558, ...
# 7   [0.21312, 0.2752, 0.32994, 0.37626, 0.42436, 0...
# 8   [0.22086, 0.27306, 0.31682, 0.37288, 0.42572, ...
# 9   [0.21488, 0.2748, 0.32014, 0.3741, 0.4263, 0.4...
# 10  [0.2152, 0.27004, 0.32858, 0.37734, 0.42328, 0...
# 11  [0.20554, 0.2766, 0.32936, 0.375, 0.42374, 0.4...
# 12  [0.21314, 0.27974, 0.32866, 0.3658, 0.41546, 0...
# 13  [0.21102, 0.27898, 0.32612, 0.37116, 0.42486, ...
# 14  [0.21518, 0.27454, 0.3253, 0.37888, 0.41928, 0...
# 15  [0.21788, 0.28354, 0.33224, 0.37614, 0.4221, 0...
# 16  [0.21382, 0.28062, 0.32742, 0.37868, 0.42558, ...
# 17  [0.21312, 0.2752, 0.32994, 0.37626, 0.42436, 0...
# 18  [0.22086, 0.27306, 0.31682, 0.37288, 0.42572, ...
# 19  [0.21488, 0.2748, 0.32014, 0.3741, 0.4263, 0.4...
#
#                                     Trn_ACC_list_top5  \
# 0   [0.48404, 0.563, 0.6247, 0.6763, 0.72438, 0.76...
# 1   [0.47886, 0.5694, 0.62636, 0.67856, 0.72226, 0...
# 2   [0.4838, 0.56904, 0.6225, 0.67062, 0.72238, 0....
# 3   [0.47792, 0.56624, 0.62628, 0.6757, 0.725, 0.7...
# 4   [0.4819, 0.56588, 0.62486, 0.6818, 0.7223, 0.7...
# 5   [0.48276, 0.57084, 0.63102, 0.67726, 0.7234, 0...
# 6   [0.48466, 0.56662, 0.62492, 0.67802, 0.72264, ...
# 7   [0.48778, 0.5663, 0.63052, 0.68164, 0.72804, 0...
# 8   [0.48822, 0.56332, 0.62104, 0.6808, 0.72558, 0...
# 9   [0.4832, 0.56474, 0.6238, 0.6777, 0.72532, 0.7...
# 10  [0.48404, 0.563, 0.6247, 0.6763, 0.72438, 0.76...
# 11  [0.47886, 0.5694, 0.62636, 0.67856, 0.72226, 0...
# 12  [0.4838, 0.56904, 0.6225, 0.67062, 0.72238, 0....
# 13  [0.47792, 0.56624, 0.62628, 0.6757, 0.725, 0.7...
# 14  [0.4819, 0.56588, 0.62486, 0.6818, 0.7223, 0.7...
# 15  [0.48276, 0.57084, 0.63102, 0.67726, 0.7234, 0...
# 16  [0.48466, 0.56662, 0.62492, 0.67802, 0.72264, ...
# 17  [0.48778, 0.5663, 0.63052, 0.68164, 0.72804, 0...
# 18  [0.48822, 0.56332, 0.62104, 0.6808, 0.72558, 0...
# 19  [0.4832, 0.56474, 0.6238, 0.6777, 0.72532, 0.7...
#
#                                     Tst_ACC_list_top1  \
# 0   [0.1895, 0.2239, 0.2533, 0.2675, 0.2762, 0.281...
# 1   [0.1831, 0.2258, 0.2514, 0.2643, 0.2757, 0.278...
# 2   [0.1863, 0.2305, 0.2511, 0.2614, 0.2748, 0.281...
# 3   [0.1869, 0.2261, 0.2507, 0.2658, 0.2764, 0.288...
# 4   [0.1893, 0.2272, 0.2523, 0.266, 0.2741, 0.2827...
# 5   [0.1898, 0.23, 0.2573, 0.2674, 0.2806, 0.2852,...
# 6   [0.1832, 0.2284, 0.2544, 0.2701, 0.2778, 0.289...
# 7   [0.1909, 0.2225, 0.2519, 0.2694, 0.2739, 0.284...
# 8   [0.1915, 0.2247, 0.2416, 0.2601, 0.2775, 0.282...
# 9   [0.1914, 0.2348, 0.2437, 0.2702, 0.2713, 0.282...
# 10  [0.1895, 0.2239, 0.2533, 0.2675, 0.2762, 0.281...
# 11  [0.1831, 0.2258, 0.2514, 0.2643, 0.2757, 0.278...
# 12  [0.1863, 0.2305, 0.2511, 0.2614, 0.2748, 0.281...
# 13  [0.1869, 0.2261, 0.2507, 0.2658, 0.2764, 0.288...
# 14  [0.1893, 0.2272, 0.2523, 0.266, 0.2741, 0.2827...
# 15  [0.1898, 0.23, 0.2573, 0.2674, 0.2806, 0.2852,...
# 16  [0.1832, 0.2284, 0.2544, 0.2701, 0.2778, 0.289...
# 17  [0.1909, 0.2225, 0.2519, 0.2694, 0.2739, 0.284...
# 18  [0.1915, 0.2247, 0.2416, 0.2601, 0.2775, 0.282...
# 19  [0.1914, 0.2348, 0.2437, 0.2702, 0.2713, 0.282...
#
#                                     Tst_ACC_list_top5  Trn_ACC_top1  \
# 0   [0.4468, 0.4901, 0.5218, 0.5412, 0.5519, 0.562...       0.98524
# 1   [0.4404, 0.504, 0.5244, 0.5404, 0.5504, 0.5623...       0.98794
# 2   [0.442, 0.499, 0.5263, 0.538, 0.5543, 0.5606, ...       0.98362
# 3   [0.4413, 0.4997, 0.5294, 0.5458, 0.5558, 0.562...       0.97116
# 4   [0.4459, 0.4992, 0.5238, 0.5454, 0.5483, 0.566...       0.98496
# 5   [0.4492, 0.4989, 0.5309, 0.5505, 0.5568, 0.566...       0.98618
# 6   [0.4487, 0.5045, 0.5231, 0.5468, 0.5547, 0.564...       0.97374
# 7   [0.4496, 0.5008, 0.5289, 0.5454, 0.5556, 0.557...       0.97794
# 8   [0.4502, 0.4934, 0.5229, 0.548, 0.5587, 0.56, ...       0.98004
# 9   [0.447, 0.4975, 0.5257, 0.5445, 0.554, 0.559, ...       0.98590
# 10  [0.4468, 0.4901, 0.5218, 0.5412, 0.5519, 0.562...       0.99340
# 11  [0.4404, 0.504, 0.5244, 0.5404, 0.5504, 0.5623...       0.99458
# 12  [0.442, 0.499, 0.5263, 0.538, 0.5543, 0.5606, ...       0.99486
# 13  [0.4413, 0.4997, 0.5294, 0.5458, 0.5558, 0.562...       0.99134
# 14  [0.4459, 0.4992, 0.5238, 0.5454, 0.5483, 0.566...       0.99594
# 15  [0.4492, 0.4989, 0.5309, 0.5505, 0.5568, 0.566...       0.99518
# 16  [0.4487, 0.5045, 0.5231, 0.5468, 0.5547, 0.564...       0.99310
# 17  [0.4496, 0.5008, 0.5289, 0.5454, 0.5556, 0.557...       0.99132
# 18  [0.4502, 0.4934, 0.5229, 0.548, 0.5587, 0.56, ...       0.98852
# 19  [0.447, 0.4975, 0.5257, 0.5445, 0.554, 0.559, ...       0.98502
#
#     Trn_ACC_top5  Tst_ACC_top1  Tst_ACC_top5
# 0        0.99992        0.2895        0.5414
# 1        0.99982        0.2882        0.5365
# 2        0.99984        0.2832        0.5390
# 3        0.99958        0.2792        0.5424
# 4        0.99990        0.2882        0.5370
# 5        0.99980        0.2899        0.5404
# 6        0.99900        0.2803        0.5259
# 7        0.99956        0.2844        0.5365
# 8        0.99954        0.2772        0.5297
# 9        0.99974        0.2867        0.5359
# 10       0.99992        0.2888        0.5390
# 11       0.99990        0.2877        0.5439
# 12       0.99990        0.2942        0.5411
# 13       0.99994        0.2915        0.5499
# 14       0.99996        0.2928        0.5422
# 15       0.99986        0.2926        0.5421
# 16       0.99982        0.2896        0.5407
# 17       0.99984        0.2880        0.5331
# 18       0.99962        0.2849        0.5384
# 19       0.99968        0.2835        0.5430

# %%
df_setting = df_results[['setting_number', 'Trn_ACC_top1', 'Tst_ACC_top1', 'Trn_ACC_top5', 'Tst_ACC_top5']].groupby('setting_number').mean().reset_index()
df_setting[['Trn_ACC_std_top1', 'Tst_ACC_std_top1', 'Trn_ACC_std_top5', 'Tst_ACC_std_top5']] = df_results[['setting_number', 'Trn_ACC_top1', 'Tst_ACC_top1', 'Trn_ACC_top5', 'Tst_ACC_top5']].groupby('setting_number').std().reset_index()[['Trn_ACC_top1', 'Tst_ACC_top1', 'Trn_ACC_top5', 'Tst_ACC_top5']]
df_setting
# Out:
#    setting_number  Trn_ACC_top1  Tst_ACC_top1  Trn_ACC_top5  Tst_ACC_top5  \
# 0               1      0.981672       0.28468      0.999670       0.53647
# 1               2      0.992326       0.28936      0.999844       0.54134
#
#    Trn_ACC_std_top1  Tst_ACC_std_top1  Trn_ACC_std_top5  Tst_ACC_std_top5
# 0          0.005724          0.004556          0.000274          0.005158
# 1          0.003404          0.003489          0.000112          0.004300

# %%
best_setting = df_setting.iloc[df_setting['Trn_ACC_top1'].argmax()]['setting_number']
best_setting
# Out:
# 2.0

# %%
data_top1 = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list_top1'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
data_top5 = np.stack(df_results.loc[df_results["setting_number"] == best_setting]['Tst_ACC_list_top5'].apply(lambda row: np.array(row)).to_numpy(), axis = 0)
# data = np.array(df_results.iloc[0]['Tst_ACC_list'])[np.newaxis]#.apply(lambda row: np.array(row)).to_numpy(), axis = 0)

# compute the mean, 25/75 percentiles, and standard deviation
mean_top1, perc_25_top1, perc_75_top1, std_data_top1 = perc(data_top1)
mean_top5, perc_25_top5, perc_75_top5, std_data_top5 = perc(data_top5)

x = np.arange(1, mean_top1.shape[0]+1)
fh2=plt.figure(figsize=(10, 6), dpi=80)

plt.plot(x, mean_top5, linewidth=4, color='k', label = "BPTT - Top-5 (%)")
plt.fill_between(x, mean_top5 - std_data_top5, mean_top5 + std_data_top5, alpha=0.25, linewidth=0, color='k')

plt.plot(x, mean_top1, linewidth=4, color='#006BB2', label = "BPTT - Top-1 (%)")
plt.fill_between(x, mean_top1 - std_data_top1, mean_top1 + std_data_top1, alpha=0.25, linewidth=0, color='#006BB2')


gh=plt.grid(linewidth=2)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Accuracy',fontsize=25)
plt.xlabel(r"Number of Epochs",fontsize=25)
# plt.title("CorInfoMax Test Accuracy on CIFAR100")
plt.legend(fontsize = 25)
plt.axis([0.0,50,mean_top1[0] - 0.01,0.60])
ApplyFont(plt.gca())
